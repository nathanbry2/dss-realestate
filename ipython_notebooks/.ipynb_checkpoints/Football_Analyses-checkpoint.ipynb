# %% [markdown]
# # Football Analyses

# %%
# importing used libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
sns.set()

# %%
df_coaches = pd.read_json('coaches.json',encoding='utf-8')
df_coaches.head()
# Out:
#      wyId      shortName      firstName middleName         lastName  \
# 0  275580  Cesar Domingo  César Domingo             Mendiondo López
# 1   14710    J. Heynckes          Josef                    Heynckes
# 2  135480    G. De Biasi       Giovanni                    De Biasi
# 3  210074      Marcelino      Marcelino                García Toral
# 4  293398      T. Korkut         Tayfun                      Korkut
#
#     birthDate                                          birthArea  \
# 0        None  {'id': 76, 'alpha2code': 'BR', 'alpha3code': '...
# 1  1945-05-09  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
# 2  1956-06-16  {'id': 380, 'alpha2code': 'IT', 'alpha3code': ...
# 3  1965-08-14  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...
# 4  1974-04-02  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
#
#                                         passportArea  currentTeamId
# 0  {'id': 76, 'alpha2code': 'BR', 'alpha3code': '...              0
# 1  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...              0
# 2  {'id': 380, 'alpha2code': 'IT', 'alpha3code': ...              0
# 3  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...            674
# 4  {'id': 792, 'alpha2code': 'TR', 'alpha3code': ...              0

# %%
df_players = pd.read_json('players_new.json',encoding='utf-8')
df_players.head()
# Out:
#                                         passportArea  weight  \
# 0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...      78
# 1  {'name': 'Senegal', 'id': '686', 'alpha3code':...      73
# 2  {'name': 'France', 'id': '250', 'alpha3code': ...      72
# 3  {'name': 'Senegal', 'id': '686', 'alpha3code':...      82
# 4  {'name': 'France', 'id': '250', 'alpha3code': ...      84
#
#            firstName middleName  lastName currentTeamId   birthDate  height  \
# 0              Harun                Tekin          4502  1989-06-17     187
# 1             Malang                 Sarr          3775  1999-01-23     182
# 2               Over             Mandanda          3772  1998-10-26     176
# 3  Alfred John Momar              N'Diaye           683  1990-03-06     187
# 4           Ibrahima               Konaté          2975  1999-05-25     192
#
#                                                 role  \
# 0  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 1  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 2  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 3  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 4  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
#
#                                            birthArea    wyId   foot  \
# 0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...   32777  right
# 1  {'name': 'France', 'id': '250', 'alpha3code': ...  393228   left
# 2  {'name': 'France', 'id': '250', 'alpha3code': ...  393230
# 3  {'name': 'France', 'id': '250', 'alpha3code': ...   32793  right
# 4  {'name': 'France', 'id': '250', 'alpha3code': ...  393247  right
#
#      shortName currentNationalTeamId
# 0     H. Tekin                  4687
# 1      M. Sarr                  4423
# 2  O. Mandanda                  null
# 3   A. N'Diaye                 19314
# 4    I. Konaté                  null

# %%
df_teams = pd.read_json('teams_new.json',encoding='utf-8')
df_teams.head()
# Out:
#                   city              name  wyId                  officialName  \
# 0  Newcastle upon Tyne  Newcastle United  1613           Newcastle United FC
# 1                 Vigo     Celta de Vigo   692       Real Club Celta de Vigo
# 2            Barcelona          Espanyol   691  Reial Club Deportiu Espanyol
# 3      Vitoria-Gasteiz  Deportivo Alavés   696              Deportivo Alavés
# 4             Valencia           Levante   695                    Levante UD
#
#                                                 area  type
# 0  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 1  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 4  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club

# %%
df_events_PL = pd.read_json('events_England.json',encoding='utf-8')
df_events_PL.head()
# Out:
#    eventId subEventName            tags  playerId  \
# 0        8  Simple pass  [{'id': 1801}]     25413
# 1        8    High pass  [{'id': 1801}]    370224
# 2        8    Head pass  [{'id': 1801}]      3319
# 3        8    Head pass  [{'id': 1801}]    120339
# 4        8  Simple pass  [{'id': 1801}]    167145
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719      Pass    1609
# 1  [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}]  2499719      Pass    1609
# 2  [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}]  2499719      Pass    1609
# 3  [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}]  2499719      Pass    1609
# 4  [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}]  2499719      Pass    1609
#
#   matchPeriod   eventSec subEventId         id
# 0          1H   2.758649         85  177959171
# 1          1H   4.946850         83  177959172
# 2          1H   6.542188         82  177959173
# 3          1H   8.143395         82  177959174
# 4          1H  10.302366         85  177959175

# %%
df_matches_PL = pd.read_json('matches_England.json',encoding='utf-8')
df_matches_PL.head()
# Out:
#    status  roundId  gameweek  \
# 0  Played  4405654        38
# 1  Played  4405654        38
# 2  Played  4405654        38
# 3  Played  4405654        38
# 4  Played  4405654        38
#
#                                            teamsData  seasonId  \
# 0  {'1646': {'scoreET': 0, 'coachId': 8880, 'side...    181150
# 1  {'1628': {'scoreET': 0, 'coachId': 8357, 'side...    181150
# 2  {'1609': {'scoreET': 0, 'coachId': 7845, 'side...    181150
# 3  {'1651': {'scoreET': 0, 'coachId': 8093, 'side...    181150
# 4  {'1644': {'scoreET': 0, 'coachId': 93112, 'sid...    181150
#
#                dateutc  winner                     venue     wyId  \
# 0  2018-05-13 14:00:00    1659                 Turf Moor  2500089
# 1  2018-05-13 14:00:00    1628             Selhurst Park  2500090
# 2  2018-05-13 14:00:00    1609  The John Smith's Stadium  2500091
# 3  2018-05-13 14:00:00    1612                   Anfield  2500092
# 4  2018-05-13 14:00:00    1611              Old Trafford  2500093
#
#                                           label  \
# 0              Burnley - AFC Bournemouth, 1 - 2
# 1  Crystal Palace - West Bromwich Albion, 2 - 0
# 2            Huddersfield Town - Arsenal, 0 - 1
# 3     Liverpool - Brighton & Hove Albion, 4 - 0
# 4            Manchester United - Watford, 1 - 0
#
#                                date  \
# 0  May 13, 2018 at 4:00:00 PM GMT+2
# 1  May 13, 2018 at 4:00:00 PM GMT+2
# 2  May 13, 2018 at 4:00:00 PM GMT+2
# 3  May 13, 2018 at 4:00:00 PM GMT+2
# 4  May 13, 2018 at 4:00:00 PM GMT+2
#
#                                             referees duration  competitionId
# 0  [{'refereeId': 385705, 'role': 'referee'}, {'r...  Regular            364
# 1  [{'refereeId': 381851, 'role': 'referee'}, {'r...  Regular            364
# 2  [{'refereeId': 384965, 'role': 'referee'}, {'r...  Regular            364
# 3  [{'refereeId': 385704, 'role': 'referee'}, {'r...  Regular            364
# 4  [{'refereeId': 381853, 'role': 'referee'}, {'r...  Regular            364

# %%
# Let's work with the df_matches_PL dataset

# %%
# here we split the column 'label' and create 4 lists containing the splitted information (home team, awayteam,
# home score and away score), for each game of the season

home_teams = []
away_teams = []
home_scores = []
away_scores = []


for index,row in df_matches_PL.iterrows():
    home_teams.append(row['label'].replace(',','-').split('-')[0].strip())
    away_teams.append(row['label'].replace(',','-').split('-')[1].strip())
    home_scores.append(row['label'].replace(',','-').split('-')[2].strip())
    away_scores.append(row['label'].replace(',','-').split('-')[3].strip())

# %%
# we create new columns in the df, containing the lists we just created

df_matches_PL['home_team'] = home_teams
df_matches_PL['away_team'] = away_teams
df_matches_PL['home_score'] = home_scores
df_matches_PL['away_score'] = away_scores

# %%
df_matches_PL.head()
# Out:
#    status  roundId  gameweek  \
# 0  Played  4405654        38
# 1  Played  4405654        38
# 2  Played  4405654        38
# 3  Played  4405654        38
# 4  Played  4405654        38
#
#                                            teamsData  seasonId  \
# 0  {'1646': {'scoreET': 0, 'coachId': 8880, 'side...    181150
# 1  {'1628': {'scoreET': 0, 'coachId': 8357, 'side...    181150
# 2  {'1609': {'scoreET': 0, 'coachId': 7845, 'side...    181150
# 3  {'1651': {'scoreET': 0, 'coachId': 8093, 'side...    181150
# 4  {'1644': {'scoreET': 0, 'coachId': 93112, 'sid...    181150
#
#                dateutc  winner                     venue     wyId  \
# 0  2018-05-13 14:00:00    1659                 Turf Moor  2500089
# 1  2018-05-13 14:00:00    1628             Selhurst Park  2500090
# 2  2018-05-13 14:00:00    1609  The John Smith's Stadium  2500091
# 3  2018-05-13 14:00:00    1612                   Anfield  2500092
# 4  2018-05-13 14:00:00    1611              Old Trafford  2500093
#
#                                           label  \
# 0              Burnley - AFC Bournemouth, 1 - 2
# 1  Crystal Palace - West Bromwich Albion, 2 - 0
# 2            Huddersfield Town - Arsenal, 0 - 1
# 3     Liverpool - Brighton & Hove Albion, 4 - 0
# 4            Manchester United - Watford, 1 - 0
#
#                                date  \
# 0  May 13, 2018 at 4:00:00 PM GMT+2
# 1  May 13, 2018 at 4:00:00 PM GMT+2
# 2  May 13, 2018 at 4:00:00 PM GMT+2
# 3  May 13, 2018 at 4:00:00 PM GMT+2
# 4  May 13, 2018 at 4:00:00 PM GMT+2
#
#                                             referees duration  competitionId  \
# 0  [{'refereeId': 385705, 'role': 'referee'}, {'r...  Regular            364
# 1  [{'refereeId': 381851, 'role': 'referee'}, {'r...  Regular            364
# 2  [{'refereeId': 384965, 'role': 'referee'}, {'r...  Regular            364
# 3  [{'refereeId': 385704, 'role': 'referee'}, {'r...  Regular            364
# 4  [{'refereeId': 381853, 'role': 'referee'}, {'r...  Regular            364
#
#            home_team               away_team home_score away_score
# 0            Burnley         AFC Bournemouth          1          2
# 1     Crystal Palace    West Bromwich Albion          2          0
# 2  Huddersfield Town                 Arsenal          0          1
# 3          Liverpool  Brighton & Hove Albion          4          0
# 4  Manchester United                 Watford          1          0

# %%
# we determine the winner and loser (or draw) for each game by comparing the home and away scores

winners = []
losers = []

for index,row in df_matches_PL.iterrows():
    if row['home_score'] > row['away_score']:
        winners.append(row['home_team'])
        losers.append(row['away_team'])
    elif row['home_score'] < row['away_score']:
        winners.append(row['away_team'])
        losers.append(row['home_team'])
    elif row['home_score'] == row['away_score']:
        winners.append('Draw')
        losers.append('Draw')

# %%
df_matches_PL['winner'] = winners
df_matches_PL['loser'] = losers

# %%
df_matches_PL.head()
# Out:
#    status  roundId  gameweek  \
# 0  Played  4405654        38
# 1  Played  4405654        38
# 2  Played  4405654        38
# 3  Played  4405654        38
# 4  Played  4405654        38
#
#                                            teamsData  seasonId  \
# 0  {'1646': {'scoreET': 0, 'coachId': 8880, 'side...    181150
# 1  {'1628': {'scoreET': 0, 'coachId': 8357, 'side...    181150
# 2  {'1609': {'scoreET': 0, 'coachId': 7845, 'side...    181150
# 3  {'1651': {'scoreET': 0, 'coachId': 8093, 'side...    181150
# 4  {'1644': {'scoreET': 0, 'coachId': 93112, 'sid...    181150
#
#                dateutc             winner                     venue     wyId  \
# 0  2018-05-13 14:00:00    AFC Bournemouth                 Turf Moor  2500089
# 1  2018-05-13 14:00:00     Crystal Palace             Selhurst Park  2500090
# 2  2018-05-13 14:00:00            Arsenal  The John Smith's Stadium  2500091
# 3  2018-05-13 14:00:00          Liverpool                   Anfield  2500092
# 4  2018-05-13 14:00:00  Manchester United              Old Trafford  2500093
#
#                                           label  \
# 0              Burnley - AFC Bournemouth, 1 - 2
# 1  Crystal Palace - West Bromwich Albion, 2 - 0
# 2            Huddersfield Town - Arsenal, 0 - 1
# 3     Liverpool - Brighton & Hove Albion, 4 - 0
# 4            Manchester United - Watford, 1 - 0
#
#                                date  \
# 0  May 13, 2018 at 4:00:00 PM GMT+2
# 1  May 13, 2018 at 4:00:00 PM GMT+2
# 2  May 13, 2018 at 4:00:00 PM GMT+2
# 3  May 13, 2018 at 4:00:00 PM GMT+2
# 4  May 13, 2018 at 4:00:00 PM GMT+2
#
#                                             referees duration  competitionId  \
# 0  [{'refereeId': 385705, 'role': 'referee'}, {'r...  Regular            364
# 1  [{'refereeId': 381851, 'role': 'referee'}, {'r...  Regular            364
# 2  [{'refereeId': 384965, 'role': 'referee'}, {'r...  Regular            364
# 3  [{'refereeId': 385704, 'role': 'referee'}, {'r...  Regular            364
# 4  [{'refereeId': 381853, 'role': 'referee'}, {'r...  Regular            364
#
#            home_team               away_team home_score away_score  \
# 0            Burnley         AFC Bournemouth          1          2
# 1     Crystal Palace    West Bromwich Albion          2          0
# 2  Huddersfield Town                 Arsenal          0          1
# 3          Liverpool  Brighton & Hove Albion          4          0
# 4  Manchester United                 Watford          1          0
#
#                     loser
# 0                 Burnley
# 1    West Bromwich Albion
# 2       Huddersfield Town
# 3  Brighton & Hove Albion
# 4                 Watford

# %% [markdown]
# ## Who's going to win the title?

# %%
#Now that we have all the data we need, let's select what we will use for question 1

df_1 = df_matches_PL[['gameweek','home_team','away_team','home_score','away_score','winner','loser','label']]
df_1.head()
# Out:
#    gameweek          home_team               away_team home_score away_score  \
# 0        38            Burnley         AFC Bournemouth          1          2
# 1        38     Crystal Palace    West Bromwich Albion          2          0
# 2        38  Huddersfield Town                 Arsenal          0          1
# 3        38          Liverpool  Brighton & Hove Albion          4          0
# 4        38  Manchester United                 Watford          1          0
#
#               winner                   loser  \
# 0    AFC Bournemouth                 Burnley
# 1     Crystal Palace    West Bromwich Albion
# 2            Arsenal       Huddersfield Town
# 3          Liverpool  Brighton & Hove Albion
# 4  Manchester United                 Watford
#
#                                           label
# 0              Burnley - AFC Bournemouth, 1 - 2
# 1  Crystal Palace - West Bromwich Albion, 2 - 0
# 2            Huddersfield Town - Arsenal, 0 - 1
# 3     Liverpool - Brighton & Hove Albion, 4 - 0
# 4            Manchester United - Watford, 1 - 0

# %%
df_teams.head()
# Out:
#                   city              name  wyId                  officialName  \
# 0  Newcastle upon Tyne  Newcastle United  1613           Newcastle United FC
# 1                 Vigo     Celta de Vigo   692       Real Club Celta de Vigo
# 2            Barcelona          Espanyol   691  Reial Club Deportiu Espanyol
# 3      Vitoria-Gasteiz  Deportivo Alavés   696              Deportivo Alavés
# 4             Valencia           Levante   695                    Levante UD
#
#                                                 area  type
# 0  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 1  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 4  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club

# %%
#just some visualization

df_1['winner'].value_counts().plot(kind='bar')
plt.show()

# %%
#just some visualization

df_1['loser'].value_counts().plot(kind='bar')
plt.show()

# %%
PL_teams = df_1['home_team'].tolist()
PL_teams = sorted(list(dict.fromkeys(PL_teams))) #deduplicate and sort

# %%
PL_teams
# Out:
# ['AFC Bournemouth',
#  'Arsenal',
#  'Brighton & Hove Albion',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Huddersfield Town',
#  'Leicester City',
#  'Liverpool',
#  'Manchester City',
#  'Manchester United',
#  'Newcastle United',
#  'Southampton',
#  'Stoke City',
#  'Swansea City',
#  'Tottenham Hotspur',
#  'Watford',
#  'West Bromwich Albion',
#  'West Ham United']

# %%
# We create a list containing each team with its number of points at the end of the season

import pylab
from numpy import cumsum
from collections import OrderedDict

lst = []

for team in PL_teams:
    points = [0]
    dftest = df_1.loc[(df_1['home_team'] == team) | (df_1['away_team'] == team)].sort_values(by='gameweek')
    for index,row in dftest.iterrows():
        if (row['winner'] == team):
            points.append(3)
        elif (row['loser'] == team):  
            points.append(0)      
        else:
            points.append(1)
            
    
    lst.append((team,sum(points)))

# Then we sort the teams according to their points (from highest to lowest), 
# and extract the team names to have the table ranking of the league

sorted_by_second = sorted(lst, key=lambda tup: tup[1])
ordered_table = [i[0] for i in sorted_by_second]
ordered_table.reverse()

# %%
ordered_table
# Out:
# ['Manchester City',
#  'Manchester United',
#  'Tottenham Hotspur',
#  'Liverpool',
#  'Chelsea',
#  'Arsenal',
#  'Burnley',
#  'Everton',
#  'Leicester City',
#  'Newcastle United',
#  'Crystal Palace',
#  'AFC Bournemouth',
#  'West Ham United',
#  'Watford',
#  'Brighton & Hove Albion',
#  'Huddersfield Town',
#  'Southampton',
#  'Swansea City',
#  'Stoke City',
#  'West Bromwich Albion']

# %%
# we create two functions that will help us determine the longest streaks

def longest_winning_streak(points):

    longest = 0
    current = 0
    for num in points:
        if num == 3:
            current += 1
        else:
            longest = max(longest, current)
            current = 0

    return max(longest, current)


def longest_losing_streak(points):

    longest = 0
    current = 0
    for num in points:
        if num == 0:
            current += 1
        else:
            longest = max(longest, current)
            current = 0

    return max(longest, current)

# %%
# and then for each team, we append to an empty list the team name, 
# its longest winning streak, and its longest losing streak

# therefore, for each team, we append to a list the result (in points won) of each game

streaks = []

for team in ordered_table:
    points = []
    dftest = df_1.loc[(df_1['home_team'] == team) | (df_1['away_team'] == team)].sort_values(by='gameweek')
    for index,row in dftest.iterrows():
        if (row['winner'] == team):
            points.append(3)
        elif (row['loser'] == team):  
            points.append(0)      
        else:
            points.append(1)
            

    streaks.append([team,longest_winning_streak(points),longest_losing_streak(points)])

# %%
streaks

#1st element = team name
#2nd = longest winning streak
#3rd = longest losing streak
# Out:
# [['Manchester City', 18, 1],
#  ['Manchester United', 4, 1],
#  ['Tottenham Hotspur', 7, 1],
#  ['Liverpool', 4, 1],
#  ['Chelsea', 4, 2],
#  ['Arsenal', 3, 3],
#  ['Burnley', 3, 3],
#  ['Everton', 2, 3],
#  ['Leicester City', 4, 3],
#  ['Newcastle United', 3, 4],
#  ['Crystal Palace', 3, 7],
#  ['AFC Bournemouth', 2, 4],
#  ['West Ham United', 2, 3],
#  ['Watford', 2, 4],
#  ['Brighton & Hove Albion', 2, 3],
#  ['Huddersfield Town', 2, 5],
#  ['Southampton', 1, 3],
#  ['Swansea City', 2, 4],
#  ['Stoke City', 1, 4],
#  ['West Bromwich Albion', 2, 8]]

# %%
# we determine the 2 teams with longest winning streaks

sorted_by_winning = sorted(streaks, key=lambda lis: lis[1])
order_winning = [i[0] for i in sorted_by_winning]
order_winning.reverse()
highest_winning_teams = order_winning[0:2]

highest_winning_teams
# Out:
# ['Manchester City', 'Tottenham Hotspur']

# %%
# we determine the 2 teams with longest losing streaks

sorted_by_losing = sorted(streaks, key=lambda lis: lis[2])
order_losing = [i[0] for i in sorted_by_losing]
order_losing.reverse()
highest_losing_teams = order_losing[0:2]

highest_losing_teams
# Out:
# ['West Bromwich Albion', 'Crystal Palace']

# %%
#Let's plot the whole thing

for team in ordered_table:
    points = [0] #we add a 0 at the beginning of the list to improve visualization 
    dftest = df_1.loc[(df_1['home_team'] == team) | (df_1['away_team'] == team)].sort_values(by='gameweek')
    for index,row in dftest.iterrows():
        if (row['winner'] == team):
            points.append(3)
        elif (row['loser'] == team):  
            points.append(0)      
        else:
            points.append(1)
    
    
    running_points = list(cumsum(points)) #we compute a running sum of each team's points to have their points after each gameweek
    
    fig = plt.figure(1, figsize=(15, 10))
    
    if team in highest_winning_teams: #we plot differently the 2 teams with longest winning streaks
        plt.plot(running_points, label = team,linestyle='dashed',linewidth=2)
    elif team in highest_losing_teams: #we plot differently the 2 teams with longest losing streaks
        plt.plot(running_points, label = team,linestyle='dotted',linewidth=2)
    else: #if no particular streak, we plot normally
        plt.plot(running_points, label = team,linestyle='solid')   

    
plt.legend()
plt.title('Points per team throughout season',size=22)
plt.xticks(np.arange(1,39))
plt.yticks(np.arange(0,105,step=10))
plt.xlabel('Gameweek',size=18)
plt.ylabel('Points',size=18)

print("The 2 teams with longest winning streaks are displayed with dashed lines --- \nThe 2 teams with longest losing streaks are displayed with dotted lines ...\n")
# Out:
# The 2 teams with longest winning streaks are displayed with dashed lines ---
# The 2 teams with longest losing streaks are displayed with dotted lines ...

# %% [markdown]
# ## Is there a home-field advantage?

# %%
#We randomly choose 5 teams

import random

temp = ordered_table.copy()
teams_list_5 = []
for i in range(5):
    teams_list_5.append(temp.pop(random.randint(0,len(temp)-1)))

# %%
teams_list_5
# Out:
# ['Watford',
#  'Liverpool',
#  'Manchester City',
#  'Newcastle United',
#  'Leicester City']

# %%
# however, as we use team names in our analysis right below, we have to select 5 teams manually
# so let's select Arsenal, Manchester City, Leicester City, Watford and Southampton

teams_list_5 = ['Arsenal','Manchester City','Leicester City','Watford','Southampton']
teams_list_5
# Out:
# ['Arsenal', 'Manchester City', 'Leicester City', 'Watford', 'Southampton']

# %%
from scipy import stats

chi_list = []

for team in teams_list_5:
    df_temp = df_1.loc[(df_1['home_team'] == team) | (df_1['away_team'] == team)]
    results = []
    side = []
    for index,row in df_temp.iterrows():
        if row['winner'] != 'Draw':
            if row['winner'] == team:
                results.append('win')
            else:
                results.append("loss")
        else: 
            results.append("draw")
        if row['home_team'] == team:
            side.append("home")
        else:
            side.append("away")
    df_results = pd.DataFrame(results, columns = ["results"])
    df_sides = pd.DataFrame(side, columns = ["side"])
    df_concat = pd.concat([df_results, df_sides], axis = 1)
    df_crosstab = pd.crosstab(df_concat['side'],df_concat['results'])      
    f_obs = np.array([df_crosstab.iloc[0][1:3].values,df_crosstab.iloc[1][1:3].values])
    
    print(team,df_crosstab,'',sep='\n')

    chi_list.append([team,stats.chi2_contingency(f_obs)[0:3]])
# Out:
# Arsenal
# results  draw  loss  win
# side
# away        4    11    4
# home        2     2   15
#
# Manchester City
# results  draw  loss  win
# side
# away        2     1   16
# home        2     1   16
#
# Leicester City
# results  draw  loss  win
# side
# away        5     9    5
# home        6     6    7
#
# Watford
# results  draw  loss  win
# side
# away        2    13    4
# home        6     6    7
#
# Southampton
# results  draw  loss  win
# side
# away        8     8    3
# home        7     8    4

# %%
chi_list[0]

#after team's name, the third value is the p-value
# Out:
# ['Arsenal', (10.100690640628722, 0.0014821376819429844, 1)]

# %% [markdown]
# #### Null hypothesis H0 is that the field doesn't significantly impact the result. We can reject it if the p-value < 0,05
# #### We notice that the first p-value (from Arsenal) is significantly lower than 0,05, which enables us to reject the null hypothesis and state that the field significantly impact on Arsenal's results. Indeed, if we take a look at their results we can see that they won almost all their home games (15 out of 19), and lost a lot of away games (11 out of 19), which confirms the huge impact of the field

# %%
chi_list[1]

#after team's name, the third value is the p-value
# Out:
# ['Manchester City', (0.0, 1.0, 1)]

# %% [markdown]
# #### Null hypothesis H0 is that the field doesn't significantly impact the result. We can reject it if the p-value < 0,05
#
# #### If we take a look at other teams and p-values, we even have a p-value of 1 for Manchester City (which is normal considering that they have exactly the same number of draw, loss and wins at home and away). This is a totally opposite result compared to Arsenal

# %% [markdown]
# ## Which teams have the youngest coaches?

# %%
df_coaches.head()
# Out:
#      wyId      shortName      firstName middleName         lastName  \
# 0  275580  Cesar Domingo  César Domingo             Mendiondo López
# 1   14710    J. Heynckes          Josef                    Heynckes
# 2  135480    G. De Biasi       Giovanni                    De Biasi
# 3  210074      Marcelino      Marcelino                García Toral
# 4  293398      T. Korkut         Tayfun                      Korkut
#
#     birthDate                                          birthArea  \
# 0        None  {'id': 76, 'alpha2code': 'BR', 'alpha3code': '...
# 1  1945-05-09  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
# 2  1956-06-16  {'id': 380, 'alpha2code': 'IT', 'alpha3code': ...
# 3  1965-08-14  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...
# 4  1974-04-02  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
#
#                                         passportArea  currentTeamId
# 0  {'id': 76, 'alpha2code': 'BR', 'alpha3code': '...              0
# 1  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...              0
# 2  {'id': 380, 'alpha2code': 'IT', 'alpha3code': ...              0
# 3  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...            674
# 4  {'id': 792, 'alpha2code': 'TR', 'alpha3code': ...              0

# %%
df_teams.head()
# Out:
#                   city              name  wyId                  officialName  \
# 0  Newcastle upon Tyne  Newcastle United  1613           Newcastle United FC
# 1                 Vigo     Celta de Vigo   692       Real Club Celta de Vigo
# 2            Barcelona          Espanyol   691  Reial Club Deportiu Espanyol
# 3      Vitoria-Gasteiz  Deportivo Alavés   696              Deportivo Alavés
# 4             Valencia           Levante   695                    Levante UD
#
#                                                 area  type
# 0  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 1  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 4  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club

# %%
df_matches_PL.head()
# Out:
#    status  roundId  gameweek  \
# 0  Played  4405654        38
# 1  Played  4405654        38
# 2  Played  4405654        38
# 3  Played  4405654        38
# 4  Played  4405654        38
#
#                                            teamsData  seasonId  \
# 0  {'1646': {'scoreET': 0, 'coachId': 8880, 'side...    181150
# 1  {'1628': {'scoreET': 0, 'coachId': 8357, 'side...    181150
# 2  {'1609': {'scoreET': 0, 'coachId': 7845, 'side...    181150
# 3  {'1651': {'scoreET': 0, 'coachId': 8093, 'side...    181150
# 4  {'1644': {'scoreET': 0, 'coachId': 93112, 'sid...    181150
#
#                dateutc             winner                     venue     wyId  \
# 0  2018-05-13 14:00:00    AFC Bournemouth                 Turf Moor  2500089
# 1  2018-05-13 14:00:00     Crystal Palace             Selhurst Park  2500090
# 2  2018-05-13 14:00:00            Arsenal  The John Smith's Stadium  2500091
# 3  2018-05-13 14:00:00          Liverpool                   Anfield  2500092
# 4  2018-05-13 14:00:00  Manchester United              Old Trafford  2500093
#
#                                           label  \
# 0              Burnley - AFC Bournemouth, 1 - 2
# 1  Crystal Palace - West Bromwich Albion, 2 - 0
# 2            Huddersfield Town - Arsenal, 0 - 1
# 3     Liverpool - Brighton & Hove Albion, 4 - 0
# 4            Manchester United - Watford, 1 - 0
#
#                                date  \
# 0  May 13, 2018 at 4:00:00 PM GMT+2
# 1  May 13, 2018 at 4:00:00 PM GMT+2
# 2  May 13, 2018 at 4:00:00 PM GMT+2
# 3  May 13, 2018 at 4:00:00 PM GMT+2
# 4  May 13, 2018 at 4:00:00 PM GMT+2
#
#                                             referees duration  competitionId  \
# 0  [{'refereeId': 385705, 'role': 'referee'}, {'r...  Regular            364
# 1  [{'refereeId': 381851, 'role': 'referee'}, {'r...  Regular            364
# 2  [{'refereeId': 384965, 'role': 'referee'}, {'r...  Regular            364
# 3  [{'refereeId': 385704, 'role': 'referee'}, {'r...  Regular            364
# 4  [{'refereeId': 381853, 'role': 'referee'}, {'r...  Regular            364
#
#            home_team               away_team home_score away_score  \
# 0            Burnley         AFC Bournemouth          1          2
# 1     Crystal Palace    West Bromwich Albion          2          0
# 2  Huddersfield Town                 Arsenal          0          1
# 3          Liverpool  Brighton & Hove Albion          4          0
# 4  Manchester United                 Watford          1          0
#
#                     loser
# 0                 Burnley
# 1    West Bromwich Albion
# 2       Huddersfield Town
# 3  Brighton & Hove Albion
# 4                 Watford

# %%
# We dig into the 'teamsData' to extract the coach of each home and away team, 
# using the powerful re library and some regular expressions

home_coach = []
away_coach = []

for index,row in df_matches_PL.iterrows():
    text = str(row['teamsData'])
    ids = re.findall('coachId(.+?),', text)
    coachId1 = int(re.findall('\d+',ids[0])[0])
    coachId2 = int(re.findall('\d+',ids[1])[0])
    sides = re.findall('side(.+?),', text)
    side1 = "".join(re.split("[^a-zA-Z]*", sides[0]))
    side2 = "".join(re.split("[^a-zA-Z]*", sides[1]))
    if side1 == 'home':
        home_coach.append(coachId1)
        away_coach.append(coachId2)
    elif side1 == 'away':
        home_coach.append(coachId2)
        away_coach.append(coachId1)
        
    
df_matches_PL['home_coachId'] = home_coach
df_matches_PL['away_coachId'] = away_coach

# %%
# we concat home and away lists

test_coach = df_matches_PL['home_coachId'].tolist() + df_matches_PL['away_coachId'].tolist()
test_team = df_matches_PL['home_team'].tolist() + df_matches_PL['away_team'].tolist()

# %%
df_team_coach_PL = pd.DataFrame(list(zip(test_team, test_coach)), columns =['team', 'coachId'])

# %%
df_team_coach_PL.sort_values(by=['team'])
# Out:
#                 team  coachId
# 59   AFC Bournemouth     8934
# 283  AFC Bournemouth     8934
# 453  AFC Bournemouth     8934
# 430  AFC Bournemouth     8934
# 314  AFC Bournemouth     8934
# ..               ...      ...
# 536  West Ham United     8235
# 318  West Ham United   269869
# 610  West Ham United     8235
# 737  West Ham United   269869
# 584  West Ham United        0
#
# [760 rows x 2 columns]

# %%
# we drop duplicate rows

deduplicated_df = df_team_coach_PL.drop_duplicates()

# %%
# we drop rows with coachId = 0 (with is mainly due to missing data)

deduplicated_df = deduplicated_df[deduplicated_df['coachId'] != 0].reset_index(drop=True)
deduplicated_df
# Out:
#                       team  coachId
# 0                  Burnley     8880
# 1           Crystal Palace     8357
# 2        Huddersfield Town    18572
# 3                Liverpool    14791
# 4        Manchester United     3295
# 5         Newcastle United   210700
# 6              Southampton     9054
# 7             Swansea City    32573
# 8        Tottenham Hotspur     3782
# 9          West Ham United     8235
# 10         Manchester City   267136
# 11       Tottenham Hotspur   292863
# 12          Leicester City   209010
# 13                 Chelsea   272869
# 14                 Arsenal     7845
# 15                 Chelsea    20454
# 16                 Everton     8541
# 17         AFC Bournemouth     8934
# 18                 Watford    93112
# 19              Stoke City     8329
# 20  Brighton & Hove Albion     8093
# 21    West Bromwich Albion     7973
# 22             Southampton   254174
# 23                 Watford    71037
# 24              Stoke City     9054
# 25            Swansea City   381291
# 26                 Everton   434992
# 27    West Bromwich Albion     9454
# 28    West Bromwich Albion   149026
# 29         West Ham United   269869
# 30                 Everton   268779
# 31          Leicester City   333782
# 32          Crystal Palace   268775
# 33          Leicester City     8214
# 34        Newcastle United   531745

# %%
# we merge our cleaned dataset with the coaches one to get the coaches information

coaches_df = pd.merge(deduplicated_df, df_coaches[['wyId','shortName','birthDate']], how='left', left_on='coachId', right_on='wyId')

# %%
coaches_df = coaches_df.dropna()

# %%
coaches_df
# Out:
#                       team  coachId      wyId         shortName   birthDate
# 0                  Burnley     8880    8880.0          S. Dyche  1971-06-28
# 1           Crystal Palace     8357    8357.0        R. Hodgson  1947-08-09
# 2        Huddersfield Town    18572   18572.0         D. Wagner  1971-10-19
# 3                Liverpool    14791   14791.0          J. Klopp  1967-06-16
# 4        Manchester United     3295    3295.0     José Mourinho  1963-01-26
# 5         Newcastle United   210700  210700.0    Rafael Benítez  1960-04-16
# 6              Southampton     9054    9054.0         M. Hughes  1963-11-01
# 7             Swansea City    32573   32573.0  Carlos Carvalhal  1965-12-04
# 9          West Ham United     8235    8235.0          D. Moyes  1963-04-25
# 10         Manchester City   267136  267136.0         Guardiola  1971-01-18
# 11       Tottenham Hotspur   292863  292863.0     M. Pochettino  1972-03-02
# 12          Leicester City   209010  209010.0           C. Puel  1961-09-02
# 13                 Chelsea   272869  272869.0          A. Conte  1969-07-31
# 14                 Arsenal     7845    7845.0         A. Wenger  1949-10-22
# 15                 Chelsea    20454   20454.0          A. Conte  1969-07-31
# 16                 Everton     8541    8541.0      S. Allardyce  1954-10-19
# 17         AFC Bournemouth     8934    8934.0           E. Howe  1977-11-29
# 18                 Watford    93112   93112.0       Javi Gracia  1970-05-01
# 19              Stoke City     8329    8329.0        P. Lambert  1969-08-07
# 20  Brighton & Hove Albion     8093    8093.0        C. Hughton  1958-12-11
# 21    West Bromwich Albion     7973    7973.0         A. Pardew  1961-07-18
# 22             Southampton   254174  254174.0     M. Pellegrino  1971-10-05
# 23                 Watford    71037   71037.0       Marco Silva  1977-07-12
# 24              Stoke City     9054    9054.0         M. Hughes  1963-11-01
# 25            Swansea City   381291  381291.0        P. Clement  1972-01-08
# 26                 Everton   434992  434992.0       D. Unsworth  1973-10-16
# 27    West Bromwich Albion     9454    9454.0         G. Megson  1959-05-02
# 28    West Bromwich Albion   149026  149026.0          T. Pulis  1958-01-16
# 29         West Ham United   269869  269869.0          S. Bilić  1968-09-11
# 30                 Everton   268779  268779.0         R. Koeman  1963-03-21
# 31          Leicester City   333782  333782.0    C. Shakespeare  1963-10-26
# 32          Crystal Palace   268775  268775.0        F. de Boer  1970-05-15
# 33          Leicester City     8214    8214.0       M. Appleton  1975-12-04
# 34        Newcastle United   531745  531745.0              Paco  1973-02-19

# %%
# we create a function computing the age from a given date

from datetime import date

def calculate_age(born):
    today = date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

# %%
# we compute the age of each coach

age_list = []

for index,row in coaches_df.iterrows():
    date_format = row['birthDate'].split('-')
    age_list.append(calculate_age(date(int(date_format[0]),int(date_format[1]),int(date_format[2]))))

# %%
coaches_df['age'] = age_list

# %%
# we only keep useful information

coaches_df2 = coaches_df[['team','shortName','birthDate','age']].sort_values(by=['birthDate'],ascending=False).reset_index(drop=True)

# %%
coaches_df2
# Out:
#                       team         shortName   birthDate  age
# 0          AFC Bournemouth           E. Howe  1977-11-29   41
# 1                  Watford       Marco Silva  1977-07-12   42
# 2           Leicester City       M. Appleton  1975-12-04   43
# 3                  Everton       D. Unsworth  1973-10-16   46
# 4         Newcastle United              Paco  1973-02-19   46
# 5        Tottenham Hotspur     M. Pochettino  1972-03-02   47
# 6             Swansea City        P. Clement  1972-01-08   47
# 7        Huddersfield Town         D. Wagner  1971-10-19   48
# 8              Southampton     M. Pellegrino  1971-10-05   48
# 9                  Burnley          S. Dyche  1971-06-28   48
# 10         Manchester City         Guardiola  1971-01-18   48
# 11          Crystal Palace        F. de Boer  1970-05-15   49
# 12                 Watford       Javi Gracia  1970-05-01   49
# 13              Stoke City        P. Lambert  1969-08-07   50
# 14                 Chelsea          A. Conte  1969-07-31   50
# 15                 Chelsea          A. Conte  1969-07-31   50
# 16         West Ham United          S. Bilić  1968-09-11   51
# 17               Liverpool          J. Klopp  1967-06-16   52
# 18            Swansea City  Carlos Carvalhal  1965-12-04   53
# 19              Stoke City         M. Hughes  1963-11-01   56
# 20             Southampton         M. Hughes  1963-11-01   56
# 21          Leicester City    C. Shakespeare  1963-10-26   56
# 22         West Ham United          D. Moyes  1963-04-25   56
# 23                 Everton         R. Koeman  1963-03-21   56
# 24       Manchester United     José Mourinho  1963-01-26   56
# 25          Leicester City           C. Puel  1961-09-02   58
# 26    West Bromwich Albion         A. Pardew  1961-07-18   58
# 27        Newcastle United    Rafael Benítez  1960-04-16   59
# 28    West Bromwich Albion         G. Megson  1959-05-02   60
# 29  Brighton & Hove Albion        C. Hughton  1958-12-11   60
# 30    West Bromwich Albion          T. Pulis  1958-01-16   61
# 31                 Everton      S. Allardyce  1954-10-19   65
# 32                 Arsenal         A. Wenger  1949-10-22   70
# 33          Crystal Palace        R. Hodgson  1947-08-09   72

# %%
# we only want one coach per team, so we keep the youngest coach for each team

coaches_df3 = coaches_df2.drop_duplicates(subset ="team")

# %%
final_df_coaches = coaches_df3.sort_values(by=['birthDate'],ascending=False).reset_index(drop=True)

# %%
# here is our final ranking for the teams with yougest coaches!

final_df_coaches
# Out:
#                       team      shortName   birthDate  age
# 0          AFC Bournemouth        E. Howe  1977-11-29   41
# 1                  Watford    Marco Silva  1977-07-12   42
# 2           Leicester City    M. Appleton  1975-12-04   43
# 3                  Everton    D. Unsworth  1973-10-16   46
# 4         Newcastle United           Paco  1973-02-19   46
# 5        Tottenham Hotspur  M. Pochettino  1972-03-02   47
# 6             Swansea City     P. Clement  1972-01-08   47
# 7        Huddersfield Town      D. Wagner  1971-10-19   48
# 8              Southampton  M. Pellegrino  1971-10-05   48
# 9                  Burnley       S. Dyche  1971-06-28   48
# 10         Manchester City      Guardiola  1971-01-18   48
# 11          Crystal Palace     F. de Boer  1970-05-15   49
# 12              Stoke City     P. Lambert  1969-08-07   50
# 13                 Chelsea       A. Conte  1969-07-31   50
# 14         West Ham United       S. Bilić  1968-09-11   51
# 15               Liverpool       J. Klopp  1967-06-16   52
# 16       Manchester United  José Mourinho  1963-01-26   56
# 17    West Bromwich Albion      A. Pardew  1961-07-18   58
# 18  Brighton & Hove Albion     C. Hughton  1958-12-11   60
# 19                 Arsenal      A. Wenger  1949-10-22   70

# %%
#and here is the matplotlib boxplot

final_df_coaches.boxplot(column=['age'])
plt.show()

# %%
# here is the seaborn boxplot

sns.boxplot(y='age',data=final_df_coaches)
plt.show()

# %%
# The green line gives us the median
# The "box" representes the Interquartile Range (IQR), with values from Q1 to Q3
# The 2 points are for the 2 outliers that are higher than the maximum (calculated by the formula Q3 + 1.5*IQR), marked by the highest line
# The lowest line gives us the minimum, calculated by the formula Q1 - 1.5*IQR

# %% [markdown]
# ## Who are the best passers?

# %%
df_players.head()
# Out:
#                                         passportArea  weight  \
# 0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...      78
# 1  {'name': 'Senegal', 'id': '686', 'alpha3code':...      73
# 2  {'name': 'France', 'id': '250', 'alpha3code': ...      72
# 3  {'name': 'Senegal', 'id': '686', 'alpha3code':...      82
# 4  {'name': 'France', 'id': '250', 'alpha3code': ...      84
#
#            firstName middleName  lastName currentTeamId   birthDate  height  \
# 0              Harun                Tekin          4502  1989-06-17     187
# 1             Malang                 Sarr          3775  1999-01-23     182
# 2               Over             Mandanda          3772  1998-10-26     176
# 3  Alfred John Momar              N'Diaye           683  1990-03-06     187
# 4           Ibrahima               Konaté          2975  1999-05-25     192
#
#                                                 role  \
# 0  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 1  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 2  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 3  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 4  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
#
#                                            birthArea    wyId   foot  \
# 0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...   32777  right
# 1  {'name': 'France', 'id': '250', 'alpha3code': ...  393228   left
# 2  {'name': 'France', 'id': '250', 'alpha3code': ...  393230
# 3  {'name': 'France', 'id': '250', 'alpha3code': ...   32793  right
# 4  {'name': 'France', 'id': '250', 'alpha3code': ...  393247  right
#
#      shortName currentNationalTeamId
# 0     H. Tekin                  4687
# 1      M. Sarr                  4423
# 2  O. Mandanda                  null
# 3   A. N'Diaye                 19314
# 4    I. Konaté                  null

# %%
# we get the id of each PL team

list_id_teams_PL = df_teams_PL['wyId'].tolist()
list_id_teams_PL
# Out:
# [1613,
#  1673,
#  10531,
#  1659,
#  1651,
#  1646,
#  1631,
#  1633,
#  1639,
#  1644,
#  1623,
#  1627,
#  1625,
#  1624,
#  1628,
#  1619,
#  1612,
#  1610,
#  1611,
#  1609]

# %%
#let's keep only players playing in PL

df_players_PL = df_players.loc[df_players['currentTeamId'].isin(list_id_teams_PL)].reset_index(drop=True)

# %%
df_players_PL.head()
# Out:
#                                         passportArea  weight   firstName  \
# 0  {'name': 'Belgium', 'id': '56', 'alpha3code': ...      91        Toby
# 1  {'name': 'Belgium', 'id': '56', 'alpha3code': ...      88         Jan
# 2  {'name': 'Denmark', 'id': '208', 'alpha3code':...      76  Christian
# 3  {'name': 'Iceland', 'id': '352', 'alpha3code':...      77     Johann
# 4  {'name': 'Morocco', 'id': '504', 'alpha3code':...      80       Nacer
#
#   middleName           lastName currentTeamId   birthDate  height  \
# 0                  Alderweireld          1624  1989-03-02     187
# 1                    Vertonghen          1624  1987-04-24     189
# 2             Dannemann Eriksen          1624  1992-02-14     180
# 3             Berg Guðmunds­son          1646  1990-10-27     186
# 4                        Chadli          1627  1989-08-02     187
#
#                                                 role  \
# 0  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 1  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 2  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 3  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 4  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
#
#                                            birthArea  wyId   foot  \
# 0  {'name': 'Belgium', 'id': '56', 'alpha3code': ...    36  right
# 1  {'name': 'Belgium', 'id': '56', 'alpha3code': ...    48   left
# 2  {'name': 'Denmark', 'id': '208', 'alpha3code':...    54  right
# 3  {'name': 'Iceland', 'id': '352', 'alpha3code':...    93   left
# 4  {'name': 'Belgium', 'id': '56', 'alpha3code': ...   261  right
#
#          shortName currentNationalTeamId
# 0  T. Alderweireld                  5629
# 1    J. Vertonghen                  5629
# 2       C. Eriksen                  7712
# 3  J. Guðmunds­son                  7839
# 4        N. Chadli                  5629

# %%
df_events_PL.head()
# Out:
#    eventId subEventName            tags  playerId  \
# 0        8  Simple pass  [{'id': 1801}]     25413
# 1        8    High pass  [{'id': 1801}]    370224
# 2        8    Head pass  [{'id': 1801}]      3319
# 3        8    Head pass  [{'id': 1801}]    120339
# 4        8  Simple pass  [{'id': 1801}]    167145
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719      Pass    1609
# 1  [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}]  2499719      Pass    1609
# 2  [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}]  2499719      Pass    1609
# 3  [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}]  2499719      Pass    1609
# 4  [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}]  2499719      Pass    1609
#
#   matchPeriod   eventSec subEventId         id
# 0          1H   2.758649         85  177959171
# 1          1H   4.946850         83  177959172
# 2          1H   6.542188         82  177959173
# 3          1H   8.143395         82  177959174
# 4          1H  10.302366         85  177959175

# %%
#Let's only keep passes!

df_passes_PL = df_events_PL.loc[df_events_PL['eventId'] == 8].reset_index(drop=True)
df_passes_PL.head()
# Out:
#    eventId subEventName            tags  playerId  \
# 0        8  Simple pass  [{'id': 1801}]     25413
# 1        8    High pass  [{'id': 1801}]    370224
# 2        8    Head pass  [{'id': 1801}]      3319
# 3        8    Head pass  [{'id': 1801}]    120339
# 4        8  Simple pass  [{'id': 1801}]    167145
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719      Pass    1609
# 1  [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}]  2499719      Pass    1609
# 2  [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}]  2499719      Pass    1609
# 3  [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}]  2499719      Pass    1609
# 4  [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}]  2499719      Pass    1609
#
#   matchPeriod   eventSec subEventId         id
# 0          1H   2.758649         85  177959171
# 1          1H   4.946850         83  177959172
# 2          1H   6.542188         82  177959173
# 3          1H   8.143395         82  177959174
# 4          1H  10.302366         85  177959175

# %%
# we determine if passes were successful or failed

pass_state = []

for index,row in df_passes_PL.iterrows():
    for value in row['tags'][-1].values():
        if value == 1801:
            pass_state.append('successful')
        elif value == 1802:
            pass_state.append('failed')

# %%
df_passes_PL['pass_status'] = pass_state

# %%
df_passes_PL.head()
# Out:
#    eventId subEventName            tags  playerId  \
# 0        8  Simple pass  [{'id': 1801}]     25413
# 1        8    High pass  [{'id': 1801}]    370224
# 2        8    Head pass  [{'id': 1801}]      3319
# 3        8    Head pass  [{'id': 1801}]    120339
# 4        8  Simple pass  [{'id': 1801}]    167145
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719      Pass    1609
# 1  [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}]  2499719      Pass    1609
# 2  [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}]  2499719      Pass    1609
# 3  [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}]  2499719      Pass    1609
# 4  [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}]  2499719      Pass    1609
#
#   matchPeriod   eventSec subEventId         id pass_status
# 0          1H   2.758649         85  177959171  successful
# 1          1H   4.946850         83  177959172  successful
# 2          1H   6.542188         82  177959173  successful
# 3          1H   8.143395         82  177959174  successful
# 4          1H  10.302366         85  177959175  successful

# %%
# we merge passes and players

df_passes_players_PL = pd.merge(df_passes_PL, df_players_PL, left_on='playerId', right_on='wyId')
df_passes_players_PL.head()
# Out:
#    eventId subEventName            tags  playerId  \
# 0        8  Simple pass  [{'id': 1801}]     25413
# 1        8    Head pass  [{'id': 1802}]     25413
# 2        8  Simple pass  [{'id': 1802}]     25413
# 3        8  Simple pass  [{'id': 1801}]     25413
# 4        8  Simple pass  [{'id': 1801}]     25413
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719      Pass    1609
# 1  [{'y': 70, 'x': 71}, {'y': 63, 'x': 71}]  2499719      Pass    1609
# 2   [{'y': 38, 'x': 30}, {'y': 0, 'x': 28}]  2499719      Pass    1609
# 3  [{'y': 33, 'x': 72}, {'y': 23, 'x': 61}]  2499719      Pass    1609
# 4  [{'y': 61, 'x': 71}, {'y': 54, 'x': 72}]  2499719      Pass    1609
#
#   matchPeriod     eventSec  ...   lastName  currentTeamId   birthDate height  \
# 0          1H     2.758649  ...  Lacazette           1609  1991-05-28    175
# 1          1H   397.881307  ...  Lacazette           1609  1991-05-28    175
# 2          1H   752.105957  ...  Lacazette           1609  1991-05-28    175
# 3          1H  1253.590895  ...  Lacazette           1609  1991-05-28    175
# 4          1H  1444.541524  ...  Lacazette           1609  1991-05-28    175
#
#                                                 role  \
# 0  {'code2': 'FW', 'code3': 'FWD', 'name': 'Forwa...
# 1  {'code2': 'FW', 'code3': 'FWD', 'name': 'Forwa...
# 2  {'code2': 'FW', 'code3': 'FWD', 'name': 'Forwa...
# 3  {'code2': 'FW', 'code3': 'FWD', 'name': 'Forwa...
# 4  {'code2': 'FW', 'code3': 'FWD', 'name': 'Forwa...
#
#                                            birthArea   wyId   foot  \
# 0  {'name': 'France', 'id': 250, 'alpha3code': 'F...  25413  right
# 1  {'name': 'France', 'id': 250, 'alpha3code': 'F...  25413  right
# 2  {'name': 'France', 'id': 250, 'alpha3code': 'F...  25413  right
# 3  {'name': 'France', 'id': 250, 'alpha3code': 'F...  25413  right
# 4  {'name': 'France', 'id': 250, 'alpha3code': 'F...  25413  right
#
#       shortName currentNationalTeamId
# 0  A. Lacazette                  null
# 1  A. Lacazette                  null
# 2  A. Lacazette                  null
# 3  A. Lacazette                  null
# 4  A. Lacazette                  null
#
# [5 rows x 27 columns]

# %%
#we get a list with each PL player with at least one attempted pass

list_players_PL = df_passes_players_PL['shortName'].tolist()
list_players_PL = sorted(list(dict.fromkeys(list_players_PL))) #deduplicate and sort

# %%
len(list_players_PL)
# Out:
# 401

# %%
# for each player, we compute the total attempted passed, total successful passes, 
# total failed passes, and ratio between successful and attempted passes

total_list = []
success_list = []
fail_list = []
ratio_list = []

for player in list_players_PL:
    success = 0
    fail = 0
    temp = df_passes_players_PL.loc[(df_passes_players_PL['shortName'] == player)]
    for index,row in temp.iterrows():
        if row['pass_status'] == 'successful':
            success += 1
        elif row['pass_status'] == 'failed':
            fail += 1
    total_passes = success+fail
    ratio = success / total_passes

    total_list.append(total_passes)
    success_list.append(success)
    fail_list.append(fail)
    ratio_list.append(ratio)

# %%
len(total_list)
# Out:
# 401

# %%
# and we create a new dataset with these values

df_final_players_passes_PL = pd.DataFrame(list(zip(list_players_PL, total_list,success_list,fail_list,ratio_list)), columns = ['shortName', 'total_passes','successful_passes','failed_passes','ratio'])
df_final_players_passes_PL.head()
# Out:
#         shortName  total_passes  successful_passes  failed_passes     ratio
# 0       A. Barnes           409                277            132  0.677262
# 1      A. Begović           612                507            105  0.828431
# 2      A. Carroll           183                129             54  0.704918
# 3  A. Christensen          1288               1211             77  0.940217
# 4    A. Cresswell          1350               1049            301  0.777037

# %%
df_final_players_passes_PL.sort_values(by=['ratio'],ascending=False).head(n=10).reset_index(drop=True)
# Out:
#         shortName  total_passes  successful_passes  failed_passes     ratio
# 0       P. Souaré             9                  9              0  1.000000
# 1       R. Harper             4                  4              0  1.000000
# 2      M. Obafemi             1                  1              0  1.000000
# 3       E. Ampadu            18                 18              0  1.000000
# 4      J. Simpson             6                  6              0  1.000000
# 5       J. Stones          1204               1175             29  0.975914
# 6        F. Delph          1584               1497             87  0.945076
# 7      V. Kompany          1391               1312             79  0.943206
# 8  A. Christensen          1288               1211             77  0.940217
# 9        P. Jones          1057                992             65  0.938505

# %% [raw]
# In order to avoid meaningless results such as players who have a ratio of 1 due to very small number of attempted passed, we will only consider players with a minimum of 40 passes, which is the average number of passes per game per player
#
# Calcul details: 330000 passes over season of 380 games = 868 ==> 22 players on the field (2*11) ==> 868 / 22 = 40 (approximately)

# %%
# keeping players with at least 40 passes attempted

df_final_3_4 = df_final_players_passes_PL[df_final_players_passes_PL['total_passes'] >= 40]

# %%
# and here is the top10 players with highest passing ratio

df_final_3_4.sort_values(by=['ratio'],ascending=False).head(n=10).reset_index(drop=True)
# Out:
#         shortName  total_passes  successful_passes  failed_passes     ratio
# 0       J. Stones          1204               1175             29  0.975914
# 1        F. Delph          1584               1497             87  0.945076
# 2      V. Kompany          1391               1312             79  0.943206
# 3  A. Christensen          1288               1211             77  0.940217
# 4        P. Jones          1057                992             65  0.938505
# 5     N. Otamendi          2964               2779            185  0.937584
# 6  Mohamed Elneny           834                781             53  0.936451
# 7     İ. Gündoğan          1350               1263             87  0.935556
# 8     V. Lindelöf           729                682             47  0.935528
# 9      M. Dembélé          1365               1273             92  0.932601

# %% [markdown]
# ## Does being a tall player mean winning more air duels?

# %%
#Let's only keep air duels

df_air_duels_PL = df_events_PL.loc[df_events_PL['subEventId'] == 10].reset_index(drop=True)
df_air_duels_PL.head()
# Out:
#    eventId subEventName                         tags  playerId  \
# 0        1     Air duel  [{'id': 701}, {'id': 1802}]      8013
# 1        1     Air duel  [{'id': 703}, {'id': 1801}]         0
# 2        1     Air duel  [{'id': 703}, {'id': 1801}]      8653
# 3        1     Air duel  [{'id': 701}, {'id': 1802}]     25413
# 4        1     Air duel  [{'id': 703}, {'id': 1801}]    192748
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 15, 'x': 39}, {'y': 20, 'x': 33}]  2499719      Duel    1631
# 1  [{'y': 85, 'x': 61}, {'y': 80, 'x': 67}]  2499719      Duel    1609
# 2  [{'y': 46, 'x': 29}, {'y': 41, 'x': 50}]  2499719      Duel    1631
# 3  [{'y': 54, 'x': 71}, {'y': 59, 'x': 50}]  2499719      Duel    1609
# 4  [{'y': 56, 'x': 60}, {'y': 49, 'x': 56}]  2499719      Duel    1631
#
#   matchPeriod   eventSec subEventId         id
# 0          1H  14.765321         10  177959189
# 1          1H  14.765321         10  177961218
# 2          1H  21.878309         10  177959191
# 3          1H  22.551816         10  177959181
# 4          1H  47.717508         10  177959210

# %%
# for each duel, we check if it is successful or failed

air_duels_state = []

for index,row in df_air_duels_PL.iterrows():
    for value in row['tags'][-1].values():
        if value == 1801:
            air_duels_state.append('successful')
        elif value == 1802:
            air_duels_state.append('failed')

# %%
df_air_duels_PL['air_duel_status'] = air_duels_state
df_air_duels_PL.head()
# Out:
#    eventId subEventName                         tags  playerId  \
# 0        1     Air duel  [{'id': 701}, {'id': 1802}]      8013
# 1        1     Air duel  [{'id': 703}, {'id': 1801}]         0
# 2        1     Air duel  [{'id': 703}, {'id': 1801}]      8653
# 3        1     Air duel  [{'id': 701}, {'id': 1802}]     25413
# 4        1     Air duel  [{'id': 703}, {'id': 1801}]    192748
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 15, 'x': 39}, {'y': 20, 'x': 33}]  2499719      Duel    1631
# 1  [{'y': 85, 'x': 61}, {'y': 80, 'x': 67}]  2499719      Duel    1609
# 2  [{'y': 46, 'x': 29}, {'y': 41, 'x': 50}]  2499719      Duel    1631
# 3  [{'y': 54, 'x': 71}, {'y': 59, 'x': 50}]  2499719      Duel    1609
# 4  [{'y': 56, 'x': 60}, {'y': 49, 'x': 56}]  2499719      Duel    1631
#
#   matchPeriod   eventSec subEventId         id air_duel_status
# 0          1H  14.765321         10  177959189          failed
# 1          1H  14.765321         10  177961218      successful
# 2          1H  21.878309         10  177959191      successful
# 3          1H  22.551816         10  177959181          failed
# 4          1H  47.717508         10  177959210      successful

# %%
# we merge air duels and players

df_air_duels_players_PL = pd.merge(df_air_duels_PL, df_players_PL, left_on='playerId', right_on='wyId')
df_air_duels_players_PL.head()
# Out:
#    eventId subEventName                         tags  playerId  \
# 0        1     Air duel  [{'id': 701}, {'id': 1802}]      8013
# 1        1     Air duel  [{'id': 702}, {'id': 1801}]      8013
# 2        1     Air duel  [{'id': 701}, {'id': 1802}]      8013
# 3        1     Air duel  [{'id': 701}, {'id': 1802}]      8013
# 4        1     Air duel  [{'id': 703}, {'id': 1801}]      8013
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 15, 'x': 39}, {'y': 20, 'x': 33}]  2499719      Duel    1631
# 1   [{'y': 22, 'x': 68}, {'y': 0, 'x': 75}]  2499719      Duel    1631
# 2  [{'y': 21, 'x': 29}, {'y': 27, 'x': 32}]  2499732      Duel    1631
# 3    [{'y': 5, 'x': 70}, {'y': 0, 'x': 48}]  2499732      Duel    1631
# 4  [{'y': 30, 'x': 90}, {'y': 36, 'x': 89}]  2499753      Duel    1631
#
#   matchPeriod     eventSec  ...    lastName  currentTeamId   birthDate height  \
# 0          1H    14.765321  ...  Albrighton           1631  1989-11-18    175
# 1          2H  1849.848781  ...  Albrighton           1631  1989-11-18    175
# 2          2H  1576.643898  ...  Albrighton           1631  1989-11-18    175
# 3          2H  2515.660502  ...  Albrighton           1631  1989-11-18    175
# 4          1H   229.451539  ...  Albrighton           1631  1989-11-18    175
#
#                                                 role  \
# 0  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 1  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 2  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 3  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 4  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
#
#                                            birthArea  wyId   foot  \
# 0  {'name': 'England', 'id': 0, 'alpha3code': 'XE...  8013  right
# 1  {'name': 'England', 'id': 0, 'alpha3code': 'XE...  8013  right
# 2  {'name': 'England', 'id': 0, 'alpha3code': 'XE...  8013  right
# 3  {'name': 'England', 'id': 0, 'alpha3code': 'XE...  8013  right
# 4  {'name': 'England', 'id': 0, 'alpha3code': 'XE...  8013  right
#
#        shortName currentNationalTeamId
# 0  M. Albrighton                  null
# 1  M. Albrighton                  null
# 2  M. Albrighton                  null
# 3  M. Albrighton                  null
# 4  M. Albrighton                  null
#
# [5 rows x 27 columns]

# %%
# we get all players with at least one attempted air duel

list_players_air_duels_PL = df_air_duels_players_PL['shortName'].tolist()
list_players_air_duels_PL = sorted(list(dict.fromkeys(list_players_air_duels_PL))) #deduplicate and sort

# %%
len(list_players_air_duels_PL)
# Out:
# 391

# %%
# for each player, we compute the total attempted air duels, total successful air duels, 
# total failed air duels, and ratio between successful and attempted air duels

total_list = []
success_list = []
fail_list = []
ratio_list = []

for player in list_players_air_duels_PL:
    success = 0
    fail = 0
    temp = df_air_duels_players_PL.loc[(df_air_duels_players_PL['shortName'] == player)]
    for index,row in temp.iterrows():
        if row['air_duel_status'] == 'successful':
            success += 1
        elif row['air_duel_status'] == 'failed':
            fail += 1
    total_air_duels = success+fail
    ratio = success / total_air_duels

    total_list.append(total_air_duels)
    success_list.append(success)
    fail_list.append(fail)
    ratio_list.append(ratio)

# %%
# we create a new dataset with all these information

df_final_players_air_duels_PL = pd.DataFrame(list(zip(list_players_air_duels_PL, total_list,success_list,fail_list,ratio_list)), columns = ['shortName', 'total_air_duels','successful_air_duels','failed_air_duels','ratio'])

# %%
df_final_players_air_duels_PL.head()
# Out:
#         shortName  total_air_duels  successful_air_duels  failed_air_duels  \
# 0       A. Barnes              371                   137               234
# 1      A. Begović               22                    20                 2
# 2      A. Carroll              153                   100                53
# 3  A. Christensen               96                    77                19
# 4    A. Cresswell              117                    71                46
#
#       ratio
# 0  0.369272
# 1  0.909091
# 2  0.653595
# 3  0.802083
# 4  0.606838

# %%
df_final_players_air_duels_PL.sort_values(by=['ratio'],ascending=False).head(n=10).reset_index(drop=True)
# Out:
#       shortName  total_air_duels  successful_air_duels  failed_air_duels  \
# 0      C. Bravo                2                     2                 0
# 1       M. Vorm                1                     1                 0
# 2  P. Gazzaniga                2                     2                 0
# 3   M. Dúbravka                5                     5                 0
# 4     K. Darlow               10                    10                 0
# 5    J. Speroni                2                     2                 0
# 6    J. Simpson                1                     1                 0
# 7       J. Hart                8                     8                 0
# 8    J. Butland               12                    12                 0
# 9     T. Heaton                2                     2                 0
#
#    ratio
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    1.0
# 8    1.0
# 9    1.0

# %% [raw]
# In order to avoid meaningless results such as players who have a ratio of 1 due to very small number of attempted air duels, we will only consider players with a minimum of 40 air duels, which is the average number of air duels per game per player
#
# Calcul details : 38000 air duels over season of 380 games = 100 per game ==> 22 players on the field (2*11) ==> 100 / 22 = 5 (approximately)

# %%
df_3_5 = df_final_players_air_duels_PL[df_final_players_air_duels_PL['total_air_duels'] >= 5]

# %%
df_3_5.sort_values(by=['ratio'],ascending=False).head(n=10).reset_index(drop=True)
# Out:
#       shortName  total_air_duels  successful_air_duels  failed_air_duels  \
# 0       M. Ryan               19                    19                 0
# 1     K. Darlow               10                    10                 0
# 2  W. Hennessey               14                    14                 0
# 3   M. Dúbravka                5                     5                 0
# 4       J. Hart                8                     8                 0
# 5    J. Butland               12                    12                 0
# 6     B. Foster               10                    10                 0
# 7   J. Pickford               27                    26                 1
# 8  Ł. Fabiański               26                    25                 1
# 9       N. Pope               24                    23                 1
#
#       ratio
# 0  1.000000
# 1  1.000000
# 2  1.000000
# 3  1.000000
# 4  1.000000
# 5  1.000000
# 6  1.000000
# 7  0.962963
# 8  0.961538
# 9  0.958333

# %%
# we notice that we only have goalkeepers in our top 10, which can be logical 
# as winning air duels is a crucial part of their game (when opponents attempt crosses and take corners) : 
# a lost duel for a goalkeeper would almost always result in a goal

# %%
#Let's get the size of these players

df_final_3_5 = pd.merge(df_3_5, df_players_PL[['shortName','height']], left_on='shortName', right_on='shortName')
df_final_3_5.head()
# Out:
#         shortName  total_air_duels  successful_air_duels  failed_air_duels  \
# 0       A. Barnes              371                   137               234
# 1      A. Begović               22                    20                 2
# 2      A. Carroll              153                   100                53
# 3  A. Christensen               96                    77                19
# 4    A. Cresswell              117                    71                46
#
#       ratio  height
# 0  0.369272     186
# 1  0.909091     199
# 2  0.653595     193
# 3  0.802083     188
# 4  0.606838     170

# %%
# to make the scatter plot clearer, we define colors for each height range

temp_height_list = df_final_3_5['height'].tolist()
temp_ratio_list = df_final_3_5['ratio'].tolist()
colors = []

for height in temp_height_list:
    if height < 160:
        colors.append('yellow')
    elif height < 170:
        colors.append('orange')
    elif height < 180:
        colors.append('red')
    elif height < 190:
        colors.append('purple')
    elif height < 200:
        colors.append('green')
    else:
        colors.append('blue')

# %%
#and we plot the whole thing

from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(temp_height_list,temp_ratio_list)

def predict(x):
   return slope * x + intercept

fitLine = predict(np.array(temp_height_list))
fig = plt.figure(1, figsize=(7, 7))
plt.scatter(temp_height_list,y=temp_ratio_list,s=30,c=colors) 
plt.plot(temp_height_list, fitLine, c='r')
plt.title('Air duels won ratio versus height',size=20)
plt.xlabel('Height',size=15)
plt.ylabel('Ratio',size=15)
plt.show()

# %% [markdown]
# #### We clearly notice that the height positively impacts the ratio of air duels won

# %% [markdown]
# ## Exploratory analyses

# %%
#Let's re-use our passes df to see if the average pass completion ratio of a team has an impact on his final ranking at the end of the season

# %%
df_passes_PL.head()
# Out:
#    eventId subEventName            tags  playerId  \
# 0        8  Simple pass  [{'id': 1801}]     25413
# 1        8    High pass  [{'id': 1801}]    370224
# 2        8    Head pass  [{'id': 1801}]      3319
# 3        8    Head pass  [{'id': 1801}]    120339
# 4        8  Simple pass  [{'id': 1801}]    167145
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719      Pass    1609
# 1  [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}]  2499719      Pass    1609
# 2  [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}]  2499719      Pass    1609
# 3  [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}]  2499719      Pass    1609
# 4  [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}]  2499719      Pass    1609
#
#   matchPeriod   eventSec subEventId         id pass_status
# 0          1H   2.758649         85  177959171  successful
# 1          1H   4.946850         83  177959172  successful
# 2          1H   6.542188         82  177959173  successful
# 3          1H   8.143395         82  177959174  successful
# 4          1H  10.302366         85  177959175  successful

# %%
df_teams_PL.head()
# Out:
#                            city                    name   wyId  \
# 0           Newcastle upon Tyne        Newcastle United   1613
# 1  Huddersfield, West Yorkshire       Huddersfield Town   1673
# 2                       Swansea            Swansea City  10531
# 3           Bournemouth, Dorset         AFC Bournemouth   1659
# 4         Brighton, East Sussex  Brighton & Hove Albion   1651
#
#                 officialName  \
# 0        Newcastle United FC
# 1       Huddersfield Town FC
# 2           Swansea City AFC
# 3            AFC Bournemouth
# 4  Brighton & Hove Albion FC
#
#                                                 area  type
# 0  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 1  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 2  {'name': 'Wales', 'id': '0', 'alpha3code': 'XW...  club
# 3  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 4  {'name': 'England', 'id': '0', 'alpha3code': '...  club

# %%
PL_teams
# Out:
# ['AFC Bournemouth',
#  'Arsenal',
#  'Brighton & Hove Albion',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Huddersfield Town',
#  'Leicester City',
#  'Liverpool',
#  'Manchester City',
#  'Manchester United',
#  'Newcastle United',
#  'Southampton',
#  'Stoke City',
#  'Swansea City',
#  'Tottenham Hotspur',
#  'Watford',
#  'West Bromwich Albion',
#  'West Ham United']

# %%
df_passes_teams_PL = pd.merge(df_passes_PL, df_teams_PL, left_on='teamId', right_on='wyId')

# %%
df_passes_teams_PL = df_passes_teams_PL.sort_values(by='name')
df_passes_teams_PL.head()
# Out:
#         eventId subEventName            tags  playerId  \
# 328656        8    Head pass  [{'id': 1802}]     11669
# 318422        8  Simple pass  [{'id': 1801}]     11669
# 318421        8   Smart pass  [{'id': 1802}]      9285
# 318420        8  Simple pass  [{'id': 1801}]      9293
# 318419        8  Simple pass  [{'id': 1801}]      9285
#
#                                        positions  matchId eventName  teamId  \
# 328656  [{'y': 30, 'x': 61}, {'y': 53, 'x': 63}]  2500089      Pass    1659
# 318422  [{'y': 38, 'x': 14}, {'y': 38, 'x': 27}]  2499846      Pass    1659
# 318421  [{'y': 17, 'x': 82}, {'y': 18, 'x': 89}]  2499846      Pass    1659
# 318420  [{'y': 13, 'x': 89}, {'y': 17, 'x': 82}]  2499846      Pass    1659
# 318419  [{'y': 11, 'x': 69}, {'y': 13, 'x': 89}]  2499846      Pass    1659
#
#        matchPeriod     eventSec subEventId         id pass_status  \
# 328656          2H  3010.063372         82  251701859      failed
# 318422          2H  1351.866940         85  208945709  successful
# 318421          2H  1257.172022         86  208945700      failed
# 318420          2H  1256.518721         85  208945698  successful
# 318419          2H  1249.954411         85  208945695  successful
#
#                        city             name  wyId     officialName  \
# 328656  Bournemouth, Dorset  AFC Bournemouth  1659  AFC Bournemouth
# 318422  Bournemouth, Dorset  AFC Bournemouth  1659  AFC Bournemouth
# 318421  Bournemouth, Dorset  AFC Bournemouth  1659  AFC Bournemouth
# 318420  Bournemouth, Dorset  AFC Bournemouth  1659  AFC Bournemouth
# 318419  Bournemouth, Dorset  AFC Bournemouth  1659  AFC Bournemouth
#
#                                                      area  type
# 328656  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 318422  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 318421  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 318420  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 318419  {'name': 'England', 'id': '0', 'alpha3code': '...  club

# %%
# for each team, we compute the number of attempted passes, successful and failed passes, and the success ratio

total_list = []
success_list = []
fail_list = []
ratio_list = []

for team in PL_teams:
    success = 0
    fail = 0
    temp = df_passes_teams_PL.loc[(df_passes_teams_PL['name'] == team)]
    for index,row in temp.iterrows():
        if row['pass_status'] == 'successful':
            success += 1
        elif row['pass_status'] == 'failed':
            fail += 1
    total_passes = success+fail
    ratio = success / total_passes

    total_list.append(total_passes)
    success_list.append(success)
    fail_list.append(fail)
    ratio_list.append(ratio)

# %%
len(total_list)
# Out:
# 20

# %%
df_final_teams_passes_PL = pd.DataFrame(list(zip(PL_teams, total_list,success_list,fail_list,ratio_list)), columns = ['name', 'total_passes','successful_passes','failed_passes','ratio'])

# %%
df_final_teams_passes_PL.head()

# %%
#we re-use the list containing the end of season total points for each team

lst
# Out:
# [('AFC Bournemouth', 44),
#  ('Arsenal', 63),
#  ('Brighton & Hove Albion', 40),
#  ('Burnley', 54),
#  ('Chelsea', 70),
#  ('Crystal Palace', 44),
#  ('Everton', 49),
#  ('Huddersfield Town', 37),
#  ('Leicester City', 47),
#  ('Liverpool', 75),
#  ('Manchester City', 100),
#  ('Manchester United', 81),
#  ('Newcastle United', 44),
#  ('Southampton', 36),
#  ('Stoke City', 33),
#  ('Swansea City', 33),
#  ('Tottenham Hotspur', 77),
#  ('Watford', 41),
#  ('West Bromwich Albion', 31),
#  ('West Ham United', 42)]

# %%
#we extract the total points

scores_list = [lst[i][1] for i in range(0,len(lst))]

# %%
scores_list
# Out:
# [44,
#  63,
#  40,
#  54,
#  70,
#  44,
#  49,
#  37,
#  47,
#  75,
#  100,
#  81,
#  44,
#  36,
#  33,
#  33,
#  77,
#  41,
#  31,
#  42]

# %%
# and we add them to our dataset

df_final_teams_passes_PL['end_season_points'] = scores_list

# %%
df_final_teams_passes_PL.head()
# Out:
#                      name  total_passes  successful_passes  failed_passes  \
# 0         AFC Bournemouth         15359              12463           2896
# 1                 Arsenal         22783              19728           3055
# 2  Brighton & Hove Albion         13944              11121           2823
# 3                 Burnley         12765               9920           2845
# 4                 Chelsea         20467              17600           2867
#
#       ratio  end_season_points
# 0  0.811446                 44
# 1  0.865909                 63
# 2  0.797547                 40
# 3  0.777125                 54
# 4  0.859921                 70

# %%
# let's plot

temp_ratio_list = df_final_teams_passes_PL['ratio'].tolist()
temp_score_list = df_final_teams_passes_PL['end_season_points'].tolist()

from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(temp_ratio_list,temp_score_list)
def predict(x):
   return slope * x + intercept
fitLine = predict(np.array(temp_ratio_list))
fig = plt.figure(1, figsize=(7, 7))
plt.scatter(temp_ratio_list,y=temp_score_list,s=30) 
plt.plot(temp_ratio_list, fitLine, c='r')
plt.title('End of season points versus passes completion ratio',size=20)
plt.xlabel('Passes completion ratio',size=15)
plt.ylabel('End of season points',size=15)
plt.show()

# %%
temp_passes_list = df_final_teams_passes_PL['total_passes'].tolist()
temp_score_list = df_final_teams_passes_PL['end_season_points'].tolist()

from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(temp_passes_list,temp_score_list)
def predict(x):
   return slope * x + intercept
fitLine = predict(np.array(temp_passes_list))
fig = plt.figure(1, figsize=(7, 7))
plt.scatter(temp_passes_list,y=temp_score_list,s=30) 
plt.plot(temp_passes_list, fitLine, c='r')
plt.title('End of season points versus attempted passes thoughout season',size=20)
plt.xlabel('Attempted passes',size=15)
plt.ylabel('End of season points',size=15)
plt.show()

# %% [markdown]
# The scatter plots right above actually confirm the dominance of Premier League's Big Six, the 6 major clubs in England, almost always being the 6 best clubs at the end of the season. The PL Big Six is composed of: Manchester United, Manchester City, Liverpool, Tottenham, Chelsea and Arsenal.
#
# The plots show us that these 6 clubs all have the ball more often that their opponents and use it with more accuracy (at least for passes). We notice that Manchester City clearly stands out from the other 5 clubs with a better accuracy and many more attempted passes (and also many more points), which was predictible as their coach is Pep Guardiola, world-known for his love for beautiful game and possession football.
#
# The 14 other clubs all have the ball less often and use it with less accuracy.

# %%
#We previously saw that height was a significant advantage in aerial duels. But what about the weight? And the body mass index (BMI)?

# %%
df_6 = pd.merge(df_3_5, df_players_PL[['shortName','height','weight']], left_on='shortName', right_on='shortName')
df_6.head()
# Out:
#         shortName  total_air_duels  successful_air_duels  failed_air_duels  \
# 0       A. Barnes              371                   137               234
# 1      A. Begović               22                    20                 2
# 2      A. Carroll              153                   100                53
# 3  A. Christensen               96                    77                19
# 4    A. Cresswell              117                    71                46
#
#       ratio  height  weight
# 0  0.369272     186      76
# 1  0.909091     199     101
# 2  0.653595     193      79
# 3  0.802083     188      78
# 4  0.606838     170      66

# %% [markdown]
# ##### The formula for the BMI is the following: weight / height**2 with the weight in kg and height in m

# %%
#Let's compute the BMI for our players!

df_6['BMI'] = round(df_6['weight'] / ((df_6['height'] / 100)**2),2)

# %%
df_6.head()
# Out:
#         shortName  total_air_duels  successful_air_duels  failed_air_duels  \
# 0       A. Barnes              371                   137               234
# 1      A. Begović               22                    20                 2
# 2      A. Carroll              153                   100                53
# 3  A. Christensen               96                    77                19
# 4    A. Cresswell              117                    71                46
#
#       ratio  height  weight    BMI
# 0  0.369272     186      76  21.97
# 1  0.909091     199     101  25.50
# 2  0.653595     193      79  21.21
# 3  0.802083     188      78  22.07
# 4  0.606838     170      66  22.84

# %%
# we use different colors for weight intervals in order to make the plot clearer

temp_weight_list = df_6['weight'].tolist()
temp_ratio_list = df_6['ratio'].tolist()
colors = []

for weight in temp_weight_list:
    if weight < 60:
        colors.append('yellow')
    elif weight < 70:
        colors.append('orange')
    elif weight < 80:
        colors.append('red')
    elif weight < 90:
        colors.append('purple')
    elif weight < 100:
        colors.append('green')
    else:
        colors.append('blue')

# %%
#and we plot!

from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(temp_weight_list,temp_ratio_list)
def predict(x):
   return slope * x + intercept
fitLine = predict(np.array(temp_weight_list))
fig = plt.figure(1, figsize=(7, 7))
plt.scatter(temp_weight_list,y=temp_ratio_list,s=30,c=colors) 
plt.plot(temp_weight_list, fitLine, c='r')
plt.title('Air duels won ratio versus weight',size=20)
plt.xlabel('Weight',size=15)
plt.ylabel('Ratio',size=15)
plt.show()

# %% [raw]
# Even though its impact is a bit smaller than height's, weight still has an important role in air duels and is definitely an asset that helps winning them

# %%
# we use different colors for BMI intervals in order to make the plot clearer

temp_BMI_list = df_6['BMI'].tolist()
temp_ratio_list = df_6['ratio'].tolist()
colors = []

for BMI in temp_BMI_list:
    if BMI < 18.5:
        colors.append('yellow')
    elif BMI <= 25:
        colors.append('red')
    else:
        colors.append('blue')

# %%
# and we plot!

from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(temp_BMI_list,temp_ratio_list)

def predict(x):
   return slope * x + intercept

fitLine = predict(np.array(temp_BMI_list))
fig = plt.figure(1, figsize=(7, 7))
plt.scatter(temp_BMI_list,y=temp_ratio_list,s=30,c=colors) 
plt.plot(temp_BMI_list, fitLine, c='r')
plt.title('Air duels won ratio versus BMI',size=20)
plt.xlabel('BMI',size=15)
plt.ylabel('Ratio',size=15)
plt.show()

# %% [raw]
# This time the plot is not convincing at all.
# It first shows that most part of BMIs are in the range (18-25) which is the healthy range. This is pretty logical: the least we can expect from an athlete is to be in top shape physically. As all our population has pretty similar attributes (a 22 BMI is not necessarily better that a 19 BMI), we can not establish trends and compare them.

# %% [markdown]
# ## What are the time slots of the match with more goals?

# %% [markdown]
# ### Barplot with the absolute frequency of goals in all the time slots

# %%
df_events_PL.head()
# Out:
#    eventId subEventName            tags  playerId  \
# 0        8  Simple pass  [{'id': 1801}]     25413
# 1        8    High pass  [{'id': 1801}]    370224
# 2        8    Head pass  [{'id': 1801}]      3319
# 3        8    Head pass  [{'id': 1801}]    120339
# 4        8  Simple pass  [{'id': 1801}]    167145
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719      Pass    1609
# 1  [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}]  2499719      Pass    1609
# 2  [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}]  2499719      Pass    1609
# 3  [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}]  2499719      Pass    1609
# 4  [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}]  2499719      Pass    1609
#
#   matchPeriod   eventSec subEventId         id
# 0          1H   2.758649         85  177959171
# 1          1H   4.946850         83  177959172
# 2          1H   6.542188         82  177959173
# 3          1H   8.143395         82  177959174
# 4          1H  10.302366         85  177959175

# %%
event_types = df_events_PL['eventName'].tolist()
event_types = sorted(list(dict.fromkeys(event_types))) #deduplicate and sort

# %%
event_types
# Out:
# ['Duel',
#  'Foul',
#  'Free Kick',
#  'Goalkeeper leaving line',
#  'Interruption',
#  'Offside',
#  'Others on the ball',
#  'Pass',
#  'Save attempt',
#  'Shot']

# %%
# we only keep events potentially leading to goals

goal_events = ['Free Kick', 'Shot']

# %%
df_goal_events = df_events_PL.loc[df_events_PL['eventName'].isin(goal_events)]
df_goal_events.head()
# Out:
#     eventId subEventName                                               tags  \
# 36        3    Free Kick                                     [{'id': 1801}]
# 46       10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 59        3     Throw in                                     [{'id': 1801}]
# 62       10         Shot  [{'id': 401}, {'id': 201}, {'id': 1211}, {'id'...
# 64        3    Goal kick                                                 []
#
#     playerId                                   positions  matchId  eventName  \
# 36         0    [{'y': 44, 'x': 65}, {'y': 31, 'x': 65}]  2499719  Free Kick
# 46     25413      [{'y': 41, 'x': 88}, {'y': 0, 'x': 0}]  2499719       Shot
# 59     14853     [{'y': 0, 'x': 94}, {'y': 41, 'x': 93}]  2499719  Free Kick
# 62     26150  [{'y': 52, 'x': 85}, {'y': 100, 'x': 100}]  2499719       Shot
# 64      7882      [{'y': 0, 'x': 0}, {'y': 44, 'x': 28}]  2499719  Free Kick
#
#     teamId matchPeriod    eventSec subEventId         id
# 36    1609          1H   74.737141         31  177959198
# 46    1609          1H   94.595788        100  177959212
# 59    1631          1H  175.308128         36  177959244
# 62    1631          1H  179.854785        100  177959247
# 64    1609          1H  196.066859         34  177959227

# %%
# for each shot and free kick, we check if it led to a goal or not

event_state = []

for index,row in df_goal_events.iterrows():
    if len(row['tags']) > 0:
        for value in row['tags'][0].values():
            if value == 101:
                event_state.append('goal')
            else:
                event_state.append('no goal')
    else:
        event_state.append('no_goal')

# %%
len(event_state)
# Out:
# 44874

# %%
# according to Wikipedia, there was 1018 goals this season, so we only have 30 missing values

event_state.count('goal')
# Out:
# 988

# %%
df_goal_events['attempt_status'] = event_state
# Out:
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_goal_events.head()
# Out:
#     eventId subEventName                                               tags  \
# 36        3    Free Kick                                     [{'id': 1801}]
# 46       10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 59        3     Throw in                                     [{'id': 1801}]
# 62       10         Shot  [{'id': 401}, {'id': 201}, {'id': 1211}, {'id'...
# 64        3    Goal kick                                                 []
#
#     playerId                                   positions  matchId  eventName  \
# 36         0    [{'y': 44, 'x': 65}, {'y': 31, 'x': 65}]  2499719  Free Kick
# 46     25413      [{'y': 41, 'x': 88}, {'y': 0, 'x': 0}]  2499719       Shot
# 59     14853     [{'y': 0, 'x': 94}, {'y': 41, 'x': 93}]  2499719  Free Kick
# 62     26150  [{'y': 52, 'x': 85}, {'y': 100, 'x': 100}]  2499719       Shot
# 64      7882      [{'y': 0, 'x': 0}, {'y': 44, 'x': 28}]  2499719  Free Kick
#
#     teamId matchPeriod    eventSec subEventId         id attempt_status
# 36    1609          1H   74.737141         31  177959198        no goal
# 46    1609          1H   94.595788        100  177959212           goal
# 59    1631          1H  175.308128         36  177959244        no goal
# 62    1631          1H  179.854785        100  177959247        no goal
# 64    1609          1H  196.066859         34  177959227        no_goal

# %%
df_goals_PL = df_goal_events[df_goal_events['attempt_status'] == 'goal']
df_goals_PL.head()
# Out:
#       eventId subEventName                                               tags  \
# 46         10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 91         10         Shot  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...
# 554        10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 898        10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 1107       10         Shot  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...
#
#       playerId                                   positions  matchId eventName  \
# 46       25413      [{'y': 41, 'x': 88}, {'y': 0, 'x': 0}]  2499719      Shot
# 91       14763  [{'y': 52, 'x': 96}, {'y': 100, 'x': 100}]  2499719      Shot
# 554      12829  [{'y': 54, 'x': 94}, {'y': 100, 'x': 100}]  2499719      Shot
# 898       7945      [{'y': 50, 'x': 92}, {'y': 0, 'x': 0}]  2499719      Shot
# 1107     12829  [{'y': 54, 'x': 92}, {'y': 100, 'x': 100}]  2499719      Shot
#
#       teamId matchPeriod     eventSec subEventId         id attempt_status
# 46      1609          1H    94.595788        100  177959212           goal
# 91      1631          1H   254.745027        100  177959280           goal
# 554     1631          1H  1710.855093        100  177959759           goal
# 898     1609          1H  2815.900791        100  177960130           goal
# 1107    1631          2H   634.312236        100  177960379           goal

# %%
# we create time intervals and classify each goal

time_list = []
interval_list = []

for index,row in df_goals_PL.iterrows():
    if row['matchPeriod'] == '1H':
        time_minutes = round((row['eventSec'] / 60),2)
    elif row['matchPeriod'] == '2H':
        time_minutes = round((row['eventSec'] / 60) + 45,2)
    time_list.append(time_minutes)
    if time_minutes < 9:
        interval = '0-9'
    elif time_minutes < 18:
        interval = '09-18'
    elif time_minutes < 27:
        interval = '18-27'
    elif time_minutes < 36:
        interval = '27-36'
    elif time_minutes < 45:
        interval = '36-45'
    elif (time_minutes > 45) & (str(row['matchPeriod']) == '1H'):
        interval = '45+'
    elif time_minutes < 54:
        interval = '45-54'
    elif time_minutes < 63:
        interval = '54-63'
    elif time_minutes < 72:
        interval = '63-72'
    elif time_minutes < 81:
        interval = '72-81'
    elif time_minutes < 90:
        interval = '81-90'
    elif time_minutes >= 90:
        interval = '90+'
    interval_list.append(interval)

# %%
df_goals_PL['event_time_minutes'] = time_list
df_goals_PL['time_interval'] = interval_list
# Out:
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_goals_PL.head()
# Out:
#       eventId subEventName                                               tags  \
# 46         10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 91         10         Shot  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...
# 554        10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 898        10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 1107       10         Shot  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...
#
#       playerId                                   positions  matchId eventName  \
# 46       25413      [{'y': 41, 'x': 88}, {'y': 0, 'x': 0}]  2499719      Shot
# 91       14763  [{'y': 52, 'x': 96}, {'y': 100, 'x': 100}]  2499719      Shot
# 554      12829  [{'y': 54, 'x': 94}, {'y': 100, 'x': 100}]  2499719      Shot
# 898       7945      [{'y': 50, 'x': 92}, {'y': 0, 'x': 0}]  2499719      Shot
# 1107     12829  [{'y': 54, 'x': 92}, {'y': 100, 'x': 100}]  2499719      Shot
#
#       teamId matchPeriod     eventSec subEventId         id attempt_status  \
# 46      1609          1H    94.595788        100  177959212           goal
# 91      1631          1H   254.745027        100  177959280           goal
# 554     1631          1H  1710.855093        100  177959759           goal
# 898     1609          1H  2815.900791        100  177960130           goal
# 1107    1631          2H   634.312236        100  177960379           goal
#
#       event_time_minutes time_interval
# 46                  1.58           0-9
# 91                  4.25           0-9
# 554                28.51         27-36
# 898                46.93           45+
# 1107               55.57         54-63

# %%
# here comes the barplot with the absolute frequency of goals in all the time slots

fig = plt.figure(1, figsize=(10, 5))
df_goals_PL['time_interval'].value_counts(normalize=True).sort_index().plot(kind='bar')
plt.title('Goals per time interval',size=20)
plt.xlabel('Time intervals (minutes)',size=15)
plt.ylabel('Goals',size=15)
plt.show()

# %% [markdown]
# ### Find the top 10 teams that score the most in the interval "81-90"

# %%
# we merge our goals df with the teams df

df_goals_teams_PL = pd.merge(df_teams_PL,df_goals_PL, left_on='wyId', right_on='teamId')
df_goals_teams_PL.head()
# Out:
#                   city              name  wyId         officialName  \
# 0  Newcastle upon Tyne  Newcastle United  1613  Newcastle United FC
# 1  Newcastle upon Tyne  Newcastle United  1613  Newcastle United FC
# 2  Newcastle upon Tyne  Newcastle United  1613  Newcastle United FC
# 3  Newcastle upon Tyne  Newcastle United  1613  Newcastle United FC
# 4  Newcastle upon Tyne  Newcastle United  1613  Newcastle United FC
#
#                                                 area  type  eventId  \
# 0  {'name': 'England', 'id': '0', 'alpha3code': '...  club       10
# 1  {'name': 'England', 'id': '0', 'alpha3code': '...  club       10
# 2  {'name': 'England', 'id': '0', 'alpha3code': '...  club       10
# 3  {'name': 'England', 'id': '0', 'alpha3code': '...  club       10
# 4  {'name': 'England', 'id': '0', 'alpha3code': '...  club       10
#
#   subEventName                                               tags  playerId  \
# 0         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...      3327
# 1         Shot  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...      8004
# 2         Shot  [{'id': 101}, {'id': 401}, {'id': 201}, {'id':...    128214
# 3         Shot  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...      8833
# 4         Shot  [{'id': 101}, {'id': 401}, {'id': 201}, {'id':...     70215
#
#    ...  matchId  eventName teamId  matchPeriod     eventSec  subEventId  \
# 0  ...  2499745       Shot   1613           1H  2106.291869         100
# 1  ...  2499745       Shot   1613           2H  1613.899075         100
# 2  ...  2499745       Shot   1613           2H  2453.135608         100
# 3  ...  2499757       Shot   1613           2H  1843.448341         100
# 4  ...  2499765       Shot   1613           1H  1122.869905         100
#
#           id  attempt_status event_time_minutes  time_interval
# 0  182168996            goal              35.10          27-36
# 1  182169697            goal              71.90          63-72
# 2  182169860            goal              85.89          81-90
# 3  186196932            goal              75.72          72-81
# 4  187995955            goal              18.71          18-27
#
# [5 rows x 21 columns]

# %%
# we only keep goals from the 81-90 time interval

df_goals_81_90_PL = df_goals_teams_PL[df_goals_teams_PL['time_interval'] == '81-90']

# %%
# first way to get a ranking

df_goals_81_90_PL['name'].value_counts()
# Out:
# Manchester City           13
# Arsenal                   11
# Manchester United          9
# Chelsea                    9
# Watford                    7
# Liverpool                  7
# Crystal Palace             7
# West Ham United            6
# AFC Bournemouth            5
# Tottenham Hotspur          5
# Southampton                4
# Burnley                    4
# West Bromwich Albion       3
# Leicester City             3
# Everton                    3
# Swansea City               3
# Newcastle United           2
# Brighton & Hove Albion     2
# Huddersfield Town          1
# Stoke City                 1
# Name: name, dtype: int64

# %%
list_teams_goals_81_90_PL = df_goals_81_90_PL['name'].tolist()
list_teams_goals_81_90_PL = sorted(list(dict.fromkeys(list_teams_goals_81_90_PL))) #deduplicate and sort

# %%
# we count goals for each team

goals_81_90_list = []


for team in list_teams_goals_81_90_PL:
    goals = 0
    for index,row in df_goals_81_90_PL.iterrows():
        if row['name'] == team:
            goals += 1

    goals_81_90_list.append(goals)

# %%
goals_81_90_list
# Out:
# [5, 11, 2, 4, 9, 7, 3, 1, 3, 7, 13, 9, 2, 4, 1, 3, 5, 7, 3, 6]

# %%
# we merge team names and goals

df_crq1_2 = pd.DataFrame(list(zip(list_teams_goals_81_90_PL, goals_81_90_list)), columns = ['name', 'goals'])

# %%
# and here is our top10!

df_crq1_2.sort_values(by=['goals'],ascending=False).head(n=10).reset_index(drop=True)
# Out:
#                 name  goals
# 0    Manchester City     13
# 1            Arsenal     11
# 2  Manchester United      9
# 3            Chelsea      9
# 4          Liverpool      7
# 5            Watford      7
# 6     Crystal Palace      7
# 7    West Ham United      6
# 8  Tottenham Hotspur      5
# 9    AFC Bournemouth      5

# %% [markdown]
# ### Show if there are players that were able to score at least one goal in 8 different intervals

# %%
df_players_PL.head()
# Out:
#                                         passportArea  weight   firstName  \
# 0  {'name': 'Belgium', 'id': '56', 'alpha3code': ...      91        Toby
# 1  {'name': 'Belgium', 'id': '56', 'alpha3code': ...      88         Jan
# 2  {'name': 'Denmark', 'id': '208', 'alpha3code':...      76  Christian
# 3  {'name': 'Iceland', 'id': '352', 'alpha3code':...      77     Johann
# 4  {'name': 'Morocco', 'id': '504', 'alpha3code':...      80       Nacer
#
#   middleName           lastName currentTeamId   birthDate  height  \
# 0                  Alderweireld          1624  1989-03-02     187
# 1                    Vertonghen          1624  1987-04-24     189
# 2             Dannemann Eriksen          1624  1992-02-14     180
# 3             Berg Guðmunds­son          1646  1990-10-27     186
# 4                        Chadli          1627  1989-08-02     187
#
#                                                 role  \
# 0  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 1  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 2  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 3  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 4  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
#
#                                            birthArea  wyId   foot  \
# 0  {'name': 'Belgium', 'id': '56', 'alpha3code': ...    36  right
# 1  {'name': 'Belgium', 'id': '56', 'alpha3code': ...    48   left
# 2  {'name': 'Denmark', 'id': '208', 'alpha3code':...    54  right
# 3  {'name': 'Iceland', 'id': '352', 'alpha3code':...    93   left
# 4  {'name': 'Belgium', 'id': '56', 'alpha3code': ...   261  right
#
#          shortName currentNationalTeamId
# 0  T. Alderweireld                  5629
# 1    J. Vertonghen                  5629
# 2       C. Eriksen                  7712
# 3  J. Guðmunds­son                  7839
# 4        N. Chadli                  5629

# %%
df_goals_PL.head()
# Out:
#       eventId subEventName                                               tags  \
# 46         10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 91         10         Shot  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...
# 554        10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 898        10         Shot  [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...
# 1107       10         Shot  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...
#
#       playerId                                   positions  matchId eventName  \
# 46       25413      [{'y': 41, 'x': 88}, {'y': 0, 'x': 0}]  2499719      Shot
# 91       14763  [{'y': 52, 'x': 96}, {'y': 100, 'x': 100}]  2499719      Shot
# 554      12829  [{'y': 54, 'x': 94}, {'y': 100, 'x': 100}]  2499719      Shot
# 898       7945      [{'y': 50, 'x': 92}, {'y': 0, 'x': 0}]  2499719      Shot
# 1107     12829  [{'y': 54, 'x': 92}, {'y': 100, 'x': 100}]  2499719      Shot
#
#       teamId matchPeriod     eventSec subEventId         id attempt_status  \
# 46      1609          1H    94.595788        100  177959212           goal
# 91      1631          1H   254.745027        100  177959280           goal
# 554     1631          1H  1710.855093        100  177959759           goal
# 898     1609          1H  2815.900791        100  177960130           goal
# 1107    1631          2H   634.312236        100  177960379           goal
#
#       event_time_minutes time_interval
# 46                  1.58           0-9
# 91                  4.25           0-9
# 554                28.51         27-36
# 898                46.93           45+
# 1107               55.57         54-63

# %%
# we merge goals df and players df, to attribute each goal to a player

df_goals_players_PL = pd.merge(df_players_PL,df_goals_PL, left_on='wyId', right_on='playerId')
df_goals_players_PL.head()
# Out:
#                                         passportArea  weight   firstName  \
# 0  {'name': 'Denmark', 'id': '208', 'alpha3code':...      76  Christian
# 1  {'name': 'Denmark', 'id': '208', 'alpha3code':...      76  Christian
# 2  {'name': 'Denmark', 'id': '208', 'alpha3code':...      76  Christian
# 3  {'name': 'Denmark', 'id': '208', 'alpha3code':...      76  Christian
# 4  {'name': 'Denmark', 'id': '208', 'alpha3code':...      76  Christian
#
#   middleName           lastName currentTeamId   birthDate  height  \
# 0             Dannemann Eriksen          1624  1992-02-14     180
# 1             Dannemann Eriksen          1624  1992-02-14     180
# 2             Dannemann Eriksen          1624  1992-02-14     180
# 3             Dannemann Eriksen          1624  1992-02-14     180
# 4             Dannemann Eriksen          1624  1992-02-14     180
#
#                                                 role  \
# 0  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 1  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 2  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 3  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 4  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
#
#                                            birthArea  ...  matchId eventName  \
# 0  {'name': 'Denmark', 'id': '208', 'alpha3code':...  ...  2499752      Shot
# 1  {'name': 'Denmark', 'id': '208', 'alpha3code':...  ...  2499778      Shot
# 2  {'name': 'Denmark', 'id': '208', 'alpha3code':...  ...  2499797      Shot
# 3  {'name': 'Denmark', 'id': '208', 'alpha3code':...  ...  2499877      Shot
# 4  {'name': 'Denmark', 'id': '208', 'alpha3code':...  ...  2499895      Shot
#
#   teamId matchPeriod     eventSec subEventId         id  attempt_status  \
# 0   1624          1H  2478.424573        100  185820356            goal
# 1   1624          2H   868.014789        100  189938706            goal
# 2   1624          2H   100.548278        100  196336835            goal
# 3   1624          2H  1734.483033        100  213058897            goal
# 4   1624          2H  2826.582836        100  215110118            goal
#
#   event_time_minutes  time_interval
# 0              41.31          36-45
# 1              59.47          54-63
# 2              46.68          45-54
# 3              73.91          72-81
# 4              92.11            90+
#
# [5 rows x 29 columns]

# %%
# we do a crosstab to get the number of goals for every time intervals for each player

players_intervals_PL = pd.crosstab(df_goals_players_PL['shortName'],df_goals_players_PL['time_interval'])
players_intervals_PL.head()
# Out:
# time_interval  0-9  09-18  18-27  27-36  36-45  45+  45-54  54-63  63-72  \
# shortName
# A. Barnes        1      0      1      0      1    0      0      2      3
# A. Carroll       0      0      0      0      0    0      0      1      0
# A. Cresswell     0      0      0      0      1    0      0      0      0
# A. Doucouré      0      0      0      1      2    1      0      0      1
# A. Gray          0      1      0      1      0    0      0      2      0
#
# time_interval  72-81  81-90  90+
# shortName
# A. Barnes          0      1    0
# A. Carroll         0      1    1
# A. Cresswell       0      0    0
# A. Doucouré        0      2    0
# A. Gray            0      1    0

# %%
# for each player, we count the number of intervals he has scored in

intervals_nbr_list = []

for index, row in players_intervals_PL.iterrows():
    nbr_intervals = 0
    for i in range(0, len(players_intervals_PL.columns)):
        if row[players_intervals_PL.columns[i]] > 0:
            nbr_intervals += 1
    intervals_nbr_list.append(nbr_intervals)

# %%
intervals_nbr_list
# Out:
# [6,
#  3,
#  1,
#  5,
#  4,
#  3,
#  3,
#  3,
#  8,
#  7,
#  4,
#  1,
#  3,
#  1,
#  5,
#  1,
#  2,
#  1,
#  2,
#  6,
#  2,
#  1,
#  1,
#  1,
#  2,
#  4,
#  2,
#  2,
#  2,
#  3,
#  2,
#  6,
#  2,
#  6,
#  2,
#  2,
#  1,
#  2,
#  7,
#  2,
#  2,
#  4,
#  5,
#  7,
#  6,
#  7,
#  3,
#  1,
#  1,
#  4,
#  2,
#  3,
#  1,
#  3,
#  2,
#  1,
#  2,
#  5,
#  1,
#  3,
#  1,
#  6,
#  1,
#  1,
#  1,
#  7,
#  1,
#  2,
#  1,
#  1,
#  4,
#  1,
#  2,
#  1,
#  7,
#  3,
#  1,
#  1,
#  9,
#  11,
#  2,
#  3,
#  2,
#  2,
#  1,
#  2,
#  5,
#  1,
#  2,
#  4,
#  2,
#  1,
#  1,
#  2,
#  4,
#  1,
#  3,
#  7,
#  2,
#  7,
#  2,
#  1,
#  1,
#  4,
#  1,
#  1,
#  1,
#  6,
#  1,
#  4,
#  2,
#  3,
#  11,
#  3,
#  1,
#  3,
#  3,
#  4,
#  3,
#  1,
#  1,
#  2,
#  1,
#  2,
#  4,
#  1,
#  1,
#  1,
#  7,
#  2,
#  1,
#  7,
#  2,
#  3,
#  8,
#  1,
#  2,
#  3,
#  4,
#  4,
#  3,
#  1,
#  3,
#  2,
#  6,
#  2,
#  1,
#  1,
#  2,
#  1,
#  4,
#  5,
#  11,
#  2,
#  1,
#  1,
#  1,
#  3,
#  1,
#  5,
#  4,
#  6,
#  1,
#  7,
#  3,
#  5,
#  4,
#  3,
#  4,
#  1,
#  1,
#  4,
#  2,
#  9,
#  9,
#  4,
#  1,
#  11,
#  3,
#  2,
#  5,
#  8,
#  7,
#  2,
#  3,
#  2,
#  1,
#  2,
#  1,
#  1,
#  1,
#  1,
#  7,
#  1,
#  7,
#  3,
#  1,
#  5,
#  5,
#  4,
#  1,
#  6,
#  2,
#  1,
#  1,
#  2,
#  3,
#  2,
#  3,
#  1,
#  3,
#  1,
#  3,
#  2,
#  2,
#  8,
#  6,
#  6,
#  9,
#  4]

# %%
players_intervals_PL['total_intervals'] = intervals_nbr_list

# %%
# we only keep players with at least 8 intervals

df_crq1_3 = players_intervals_PL[players_intervals_PL['total_intervals'] >= 8]

# %%
# and here are our players with goals in at least 8 different time slots!

df_crq1_3.sort_values(by=['total_intervals'],ascending=False)
# Out:
# time_interval    0-9  09-18  18-27  27-36  36-45  45+  45-54  54-63  63-72  \
# shortName
# H. Kane            4      1      2      2      2    0      7      2      3
# J. Vardy           2      3      3      1      1    0      1      2      3
# Mohamed Salah      2      1      3      2      6    0      3      2      4
# R. Sterling        2      1      1      1      1    0      2      1      2
# Gabriel Jesus      0      2      2      0      2    1      2      1      0
# R. Lukaku          1      0      3      1      1    0      1      2      3
# R. Mahrez          0      2      1      0      1    1      1      2      0
# Álvaro Morata      1      1      0      2      2    0      1      1      1
# A. Lacazette       2      1      3      0      0    1      1      0      2
# M. Arnautović      2      1      0      0      0    1      1      1      1
# Roberto Firmino    1      1      0      1      0    1      3      4      3
# W. Zaha            1      1      1      1      2    0      0      0      1
#
# time_interval    72-81  81-90  90+  total_intervals
# shortName
# H. Kane              4      1    1               11
# J. Vardy             2      1    1               11
# Mohamed Salah        5      3    1               11
# R. Sterling          1      4    2               11
# Gabriel Jesus        1      1    1                9
# R. Lukaku            2      2    0                9
# R. Mahrez            1      1    2                9
# Álvaro Morata        1      1    0                9
# A. Lacazette         1      3    0                8
# M. Arnautović        3      1    0                8
# Roberto Firmino      0      1    0                8
# W. Zaha              1      0    1                8

# %% [markdown]
# ## Visualize movements and passes on the pitch!

# %% [markdown]
# #### 1) Considering only the match Barcelona - Real Madrid played on the 6 May 2018

# %%
import matplotlib

#here is our function that will draw the pitch

def draw_pitch(ax):
    # focus on only half of the pitch
    #Pitch Outline & Centre Line
    Pitch = plt.Rectangle([0,0], width = 120, height = 80, fill = False,color="black")
    #Left, Right Penalty Area and midline
    LeftPenalty = plt.Rectangle([0,22.3], width = 14.6, height = 35.3, fill = False,color="black")
    RightPenalty = plt.Rectangle([105.4,22.3], width = 14.6, height = 35.3, fill = False,color="black")
    midline = matplotlib.patches.ConnectionPatch([60,0], [60,80], "data", "data",color="black")

    #Left, Right 6-yard Box
    LeftSixYard = plt.Rectangle([0,32], width = 4.9, height = 16, fill = False,color="black")
    RightSixYard = plt.Rectangle([115.1,32], width = 4.9, height = 16, fill = False,color="black")


    #Prepare Circles
    centreCircle = plt.Circle((60,40),8.1,color="black", fill = False)
    centreSpot = plt.Circle((60,40),0.71,color="black")
    #Penalty spots and Arcs around penalty boxes
    leftPenSpot = plt.Circle((9.7,40),0.71,color="black")
    rightPenSpot = plt.Circle((110.3,40),0.71,color="black")
    leftArc = matplotlib.patches.Arc((9.7,40),height=16.2,width=16.2,angle=0,theta1=310,theta2=50,color="black")
    rightArc = matplotlib.patches.Arc((110.3,40),height=16.2,width=16.2,angle=0,theta1=130,theta2=230,color="black")
    
    element = [Pitch, LeftPenalty, RightPenalty, midline, LeftSixYard, RightSixYard, centreCircle, 
               centreSpot, rightPenSpot, leftPenSpot, leftArc, rightArc]
    for i in element:
        ax.add_patch(i)

# %%
#Let's try to draw a full football pitch

fig=plt.figure() #set up the figures
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)
draw_pitch(ax) #overlay our different objects on the pitch
plt.ylim(-2, 82)
plt.xlim(-2, 122)
plt.axis('off')
plt.show()

# %%
#Let's import La Liga matches data

df_matches_Liga =  pd.read_json('matches_Spain.json',encoding='utf-8')
df_matches_Liga.head()
# Out:
#    status  roundId  gameweek  \
# 0  Played  4406122        38
# 1  Played  4406122        38
# 2  Played  4406122        38
# 3  Played  4406122        38
# 4  Played  4406122        38
#
#                                            teamsData  seasonId  \
# 0  {'676': {'scoreET': 0, 'coachId': 92894, 'side...    181144
# 1  {'679': {'scoreET': 0, 'coachId': 3427, 'side'...    181144
# 2  {'691': {'scoreET': 0, 'coachId': 444778, 'sid...    181144
# 3  {'674': {'scoreET': 0, 'coachId': 210074, 'sid...    181144
# 4  {'675': {'scoreET': 0, 'coachId': 275283, 'sid...    181144
#
#                dateutc  winner                        venue     wyId  \
# 0  2018-05-20 18:45:00     676                     Camp Nou  2565922
# 1  2018-05-20 16:30:00       0  Estadio Wanda Metropolitano  2565925
# 2  2018-05-20 14:15:00     691             San Mamés Barria  2565919
# 3  2018-05-20 10:00:00     674          Estadio de Mestalla  2565924
# 4  2018-05-19 18:45:00       0       Estadio de la Cerámica  2565927
#
#                                    label                               date  \
# 0       Barcelona - Real Sociedad, 1 - 0   May 20, 2018 at 8:45:00 PM GMT+2
# 1         Atlético Madrid - Eibar, 2 - 2   May 20, 2018 at 6:30:00 PM GMT+2
# 2        Athletic Club - Espanyol, 0 - 1   May 20, 2018 at 4:15:00 PM GMT+2
# 3  Valencia - Deportivo La Coruña, 2 - 1  May 20, 2018 at 12:00:00 PM GMT+2
# 4        Villarreal - Real Madrid, 2 - 2   May 19, 2018 at 8:45:00 PM GMT+2
#
#                                             referees duration  competitionId
# 0  [{'refereeId': 398931, 'role': 'referee'}, {'r...  Regular            795
# 1  [{'refereeId': 395056, 'role': 'referee'}, {'r...  Regular            795
# 2  [{'refereeId': 384957, 'role': 'referee'}, {'r...  Regular            795
# 3  [{'refereeId': 398913, 'role': 'referee'}, {'r...  Regular            795
# 4  [{'refereeId': 395085, 'role': 'referee'}, {'r...  Regular            795

# %%
#by looking at the data we find the id of the Clasico game we are interested in

df_classico = df_matches_Liga[df_matches_Liga['wyId'] == 2565907]
df_classico.head()
# Out:
#     status  roundId  gameweek  \
# 23  Played  4406122        36
#
#                                             teamsData  seasonId  \
# 23  {'675': {'scoreET': 0, 'coachId': 275283, 'sid...    181144
#
#                 dateutc  winner     venue     wyId  \
# 23  2018-05-06 18:45:00       0  Camp Nou  2565907
#
#                              label                             date  \
# 23  Barcelona - Real Madrid, 2 - 2  May 6, 2018 at 8:45:00 PM GMT+2
#
#                                              referees duration  competitionId
# 23  [{'refereeId': 378950, 'role': 'referee'}, {'r...  Regular            795

# %%
#Let's import La Liga events data

df_events_Liga =  pd.read_json('events_Spain.json',encoding='utf-8')
df_events_Liga.head()
# Out:
#    eventId subEventName            tags  playerId  \
# 0        8  Simple pass  [{'id': 1801}]      3542
# 1        8  Simple pass  [{'id': 1801}]    274435
# 2        8  Simple pass  [{'id': 1801}]    364860
# 3        8  Simple pass  [{'id': 1801}]      3534
# 4        8  Simple pass  [{'id': 1801}]      3695
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 61, 'x': 37}, {'y': 50, 'x': 50}]  2565548      Pass     682
# 1  [{'y': 50, 'x': 50}, {'y': 30, 'x': 45}]  2565548      Pass     682
# 2  [{'y': 30, 'x': 45}, {'y': 12, 'x': 38}]  2565548      Pass     682
# 3  [{'y': 12, 'x': 38}, {'y': 69, 'x': 32}]  2565548      Pass     682
# 4  [{'y': 69, 'x': 32}, {'y': 37, 'x': 31}]  2565548      Pass     682
#
#   matchPeriod   eventSec subEventId         id
# 0          1H   2.994582         85  180864419
# 1          1H   3.137020         85  180864418
# 2          1H   6.709668         85  180864420
# 3          1H   8.805497         85  180864421
# 4          1H  14.047492         85  180864422

# %%
#we only keep the events that happened during El Clasico

df_events_classico = df_events_Liga[df_events_Liga['matchId'] == 2565907]
df_events_classico.head()
# Out:
#         eventId subEventName            tags  playerId  \
# 593455        8  Simple pass  [{'id': 1801}]      3321
# 593456        8  Simple pass  [{'id': 1801}]     14723
# 593457        8  Simple pass  [{'id': 1801}]      3306
# 593458        8  Simple pass  [{'id': 1801}]      3309
# 593459        8  Simple pass  [{'id': 1801}]      3915
#
#                                        positions  matchId eventName  teamId  \
# 593455  [{'y': 49, 'x': 50}, {'y': 40, 'x': 37}]  2565907      Pass     675
# 593456  [{'y': 40, 'x': 37}, {'y': 23, 'x': 30}]  2565907      Pass     675
# 593457  [{'y': 23, 'x': 30}, {'y': 57, 'x': 26}]  2565907      Pass     675
# 593458   [{'y': 57, 'x': 26}, {'y': 40, 'x': 8}]  2565907      Pass     675
# 593459   [{'y': 40, 'x': 8}, {'y': 14, 'x': 11}]  2565907      Pass     675
#
#        matchPeriod   eventSec subEventId         id
# 593455          1H   3.274992         85  249644096
# 593456          1H   5.109197         85  249644097
# 593457          1H   7.109958         85  249644098
# 593458          1H   8.912297         85  249644099
# 593459          1H  11.290220         85  249644100

# %%
df_players.head()
# Out:
#                                         passportArea  weight  \
# 0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...      78
# 1  {'name': 'Senegal', 'id': '686', 'alpha3code':...      73
# 2  {'name': 'France', 'id': '250', 'alpha3code': ...      72
# 3  {'name': 'Senegal', 'id': '686', 'alpha3code':...      82
# 4  {'name': 'France', 'id': '250', 'alpha3code': ...      84
#
#            firstName middleName  lastName currentTeamId   birthDate  height  \
# 0              Harun                Tekin          4502  1989-06-17     187
# 1             Malang                 Sarr          3775  1999-01-23     182
# 2               Over             Mandanda          3772  1998-10-26     176
# 3  Alfred John Momar              N'Diaye           683  1990-03-06     187
# 4           Ibrahima               Konaté          2975  1999-05-25     192
#
#                                                 role  \
# 0  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 1  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 2  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 3  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 4  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
#
#                                            birthArea    wyId   foot  \
# 0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...   32777  right
# 1  {'name': 'France', 'id': '250', 'alpha3code': ...  393228   left
# 2  {'name': 'France', 'id': '250', 'alpha3code': ...  393230
# 3  {'name': 'France', 'id': '250', 'alpha3code': ...   32793  right
# 4  {'name': 'France', 'id': '250', 'alpha3code': ...  393247  right
#
#      shortName currentNationalTeamId
# 0     H. Tekin                  4687
# 1      M. Sarr                  4423
# 2  O. Mandanda                  null
# 3   A. N'Diaye                 19314
# 4    I. Konaté                  null

# %%
#we find Cristiano Ronaldo's id

cr7 = df_players[df_players['shortName'] == 'Cristiano Ronaldo']
cr7.head()
# Out:
#                                           passportArea  weight  \
# 185  {'name': 'Portugal', 'id': '620', 'alpha3code'...      83
#
#              firstName middleName           lastName currentTeamId  \
# 185  Cristiano Ronaldo             dos Santos Aveiro          3159
#
#       birthDate  height                                               role  \
# 185  1985-02-05     187  {'code2': 'FW', 'code3': 'FWD', 'name': 'Forwa...
#
#                                              birthArea  wyId   foot  \
# 185  {'name': 'Portugal', 'id': '620', 'alpha3code'...  3322  right
#
#              shortName currentNationalTeamId
# 185  Cristiano Ronaldo                  9905

# %%
#we find Messi's id

messi = df_players[df_players['shortName'] == 'L. Messi']
messi.head()
# Out:
#                                           passportArea  weight      firstName  \
# 207  {'name': 'Spain', 'id': '724', 'alpha3code': '...      72  Lionel Andrés
#
#     middleName          lastName currentTeamId   birthDate  height  \
# 207             Messi Cuccittini           676  1987-06-24     170
#
#                                                   role  \
# 207  {'code2': 'FW', 'code3': 'FWD', 'name': 'Forwa...
#
#                                              birthArea  wyId  foot shortName  \
# 207  {'name': 'Argentina', 'id': '32', 'alpha3code'...  3359  left  L. Messi
#
#     currentNationalTeamId
# 207                 12274

# %%
# we store Cristiano Ronaldo's events

df_events_CR7 = df_events_classico[df_events_classico['playerId'] == 3322]
df_events_CR7.head()
# Out:
#         eventId            subEventName  \
# 593473        1  Ground loose ball duel
# 593475        1                Air duel
# 593497        1   Ground defending duel
# 593552        1   Ground attacking duel
# 593554        8                   Cross
#
#                                             tags  playerId  \
# 593473               [{'id': 702}, {'id': 1801}]      3322
# 593475               [{'id': 701}, {'id': 1802}]      3322
# 593497               [{'id': 701}, {'id': 1802}]      3322
# 593552  [{'id': 502}, {'id': 703}, {'id': 1801}]      3322
# 593554  [{'id': 401}, {'id': 801}, {'id': 1802}]      3322
#
#                                         positions  matchId eventName  teamId  \
# 593473   [{'y': 19, 'x': 49}, {'y': 17, 'x': 49}]  2565907      Duel     675
# 593475   [{'y': 17, 'x': 49}, {'y': 19, 'x': 38}]  2565907      Duel     675
# 593497   [{'y': 13, 'x': 65}, {'y': 23, 'x': 53}]  2565907      Duel     675
# 593552    [{'y': 12, 'x': 93}, {'y': 8, 'x': 97}]  2565907      Duel     675
# 593554  [{'y': 8, 'x': 97}, {'y': 100, 'x': 100}]  2565907      Pass     675
#
#        matchPeriod    eventSec subEventId         id
# 593473          1H   68.618689         13  249644112
# 593475          1H   69.411334         10  249644113
# 593497          1H  114.548692         12  249644119
# 593552          1H  275.327960         11  249644145
# 593554          1H  277.578035         80  249644146

# %%
# we store Messi's events

df_events_messi = df_events_classico[df_events_classico['playerId'] == 3359]
df_events_messi.head()
# Out:
#         eventId           subEventName                         tags  playerId  \
# 593485        8            Simple pass               [{'id': 1801}]      3359
# 593489        8            Simple pass               [{'id': 1801}]      3359
# 593499        8            Simple pass               [{'id': 1801}]      3359
# 593501        1  Ground attacking duel  [{'id': 702}, {'id': 1801}]      3359
# 593503        8            Simple pass               [{'id': 1801}]      3359
#
#                                        positions  matchId eventName  teamId  \
# 593485  [{'y': 87, 'x': 74}, {'y': 91, 'x': 80}]  2565907      Pass     676
# 593489  [{'y': 87, 'x': 67}, {'y': 71, 'x': 43}]  2565907      Pass     676
# 593499  [{'y': 66, 'x': 58}, {'y': 78, 'x': 75}]  2565907      Pass     676
# 593501  [{'y': 67, 'x': 65}, {'y': 38, 'x': 63}]  2565907      Duel     676
# 593503  [{'y': 38, 'x': 63}, {'y': 43, 'x': 69}]  2565907      Pass     676
#
#        matchPeriod    eventSec subEventId         id
# 593485          1H   85.701277         85  249644574
# 593489          1H   92.114223         85  249644578
# 593499          1H  117.241765         85  249644587
# 593501          1H  122.168204         11  249644589
# 593503          1H  124.686582         85  249644590

# %%
# we only keep relevant events for both players
relevant_events = ['Duel', 'Pass', 'Shot', 'Free Kick']

df_events_CR7 = df_events_CR7[df_events_CR7['eventName'].isin(relevant_events)]
df_events_messi = df_events_messi[df_events_messi['eventName'].isin(relevant_events)]

# %%
# we get starting and ending positions for all events using the powerful re library

y_start = []
x_start = []
y_end = []
x_end = []

for index,row in df_events_CR7.iterrows():
    int_list = [int(s) for s in re.findall(r'\b\d+\b', str(row['positions']))]
    y_start.append(0.8*int_list[0])
    x_start.append(120-1.2*int_list[1])
    y_end.append(0.8*int_list[2])
    x_end.append(120-1.2*int_list[3])

# %%
df_events_CR7['y_start'] = y_start
df_events_CR7['x_start'] = x_start
df_events_CR7['y_end'] = y_end
df_events_CR7['x_end'] = x_end

# %%
df_events_CR7.head()
# Out:
#         eventId            subEventName  \
# 593473        1  Ground loose ball duel
# 593475        1                Air duel
# 593497        1   Ground defending duel
# 593552        1   Ground attacking duel
# 593554        8                   Cross
#
#                                             tags  playerId  \
# 593473               [{'id': 702}, {'id': 1801}]      3322
# 593475               [{'id': 701}, {'id': 1802}]      3322
# 593497               [{'id': 701}, {'id': 1802}]      3322
# 593552  [{'id': 502}, {'id': 703}, {'id': 1801}]      3322
# 593554  [{'id': 401}, {'id': 801}, {'id': 1802}]      3322
#
#                                         positions  matchId eventName  teamId  \
# 593473   [{'y': 19, 'x': 49}, {'y': 17, 'x': 49}]  2565907      Duel     675
# 593475   [{'y': 17, 'x': 49}, {'y': 19, 'x': 38}]  2565907      Duel     675
# 593497   [{'y': 13, 'x': 65}, {'y': 23, 'x': 53}]  2565907      Duel     675
# 593552    [{'y': 12, 'x': 93}, {'y': 8, 'x': 97}]  2565907      Duel     675
# 593554  [{'y': 8, 'x': 97}, {'y': 100, 'x': 100}]  2565907      Pass     675
#
#        matchPeriod    eventSec subEventId         id  y_start  x_start  y_end  \
# 593473          1H   68.618689         13  249644112     15.2     61.2   13.6
# 593475          1H   69.411334         10  249644113     13.6     61.2   15.2
# 593497          1H  114.548692         12  249644119     10.4     42.0   18.4
# 593552          1H  275.327960         11  249644145      9.6      8.4    6.4
# 593554          1H  277.578035         80  249644146      6.4      3.6   80.0
#
#         x_end
# 593473   61.2
# 593475   74.4
# 593497   56.4
# 593552    3.6
# 593554    0.0

# %%
#CR7 heatmap

fig, ax = plt.subplots()
fig.set_size_inches(7, 5)
#ax=fig.add_subplot(1,1,1)
draw_pitch(ax) #overlay our different objects on the pitch
plt.ylim(-2, 82)
plt.xlim(-2, 122)
plt.axis('on')


x_coord = df_events_CR7['x_start'].tolist()
y_coord = df_events_CR7['y_start'].tolist()

#shades: give us the heat map we desire
# n_levels: draw more lines, the larger n, the more blurry it looks
sns.kdeplot(x_coord, y_coord, shade = "True", color = "green", n_levels = 15)
plt.show()

# %% [raw]
# Cristiano Ronaldo's heatmap is actually pretty predictible as we know he plays as a Left Winger (so down le left side of the pitch), with a weak implication in defensive tasks (which is why the down part of left side is much clearer than the high part) but also a huge goal appetite which leads to the strong presence in the penalty area

# %%
# we get starting and ending positions for all events using the powerful re library

y_start = []
x_start = []
y_end = []
x_end = []

for index,row in df_events_messi.iterrows():
    int_list = [int(s) for s in re.findall(r'\b\d+\b', str(row['positions']))]
    y_start.append(0.8*int_list[0])
    x_start.append(120-1.2*int_list[1])
    y_end.append(0.8*int_list[2])
    x_end.append(120-1.2*int_list[3])

# %%
df_events_messi['y_start'] = y_start
df_events_messi['x_start'] = x_start
df_events_messi['y_end'] = y_end
df_events_messi['x_end'] = x_end

# %%
#Messi heatmap

fig, ax = plt.subplots()
fig.set_size_inches(7, 5)
#ax=fig.add_subplot(1,1,1)
draw_pitch(ax) #overlay our different objects on the pitch
plt.ylim(-2, 82)
plt.xlim(-2, 122)
plt.axis('on')


x_coord = df_events_messi['x_start'].tolist()
y_coord = df_events_messi['y_start'].tolist()

#shades: give us the heat map we desire
# n_levels: draw more lines, the larger n, the more blurry it looks
sns.kdeplot(x_coord, y_coord, shade = "True", color = "green", n_levels = 15)
plt.show()

# %% [raw]
# When we take a look at Messi's heatmap we notice that he plays at a very central position, with a number 10 role. His presence in the box is consequently smaller than Ronaldo's one. As Cristiano Ronaldo, Messi doesn't participate much in the defensive effort. Indeed, the fact that the pitch is not coloured around FC Barcelona's goals shows us that Messi doesn't even comes back to his penalty area when Real Madrid are taking set-pieces such as free-kicks or corner kicks.

# %% [markdown]
# #### 2) Considering only the match Juventus - Napoli played on the 22 April 2018

# %%
df_matches_SerieA =  pd.read_json('matches_Italy.json',encoding='utf-8')
df_matches_SerieA.head(n=5)
# Out:
#    status  roundId  gameweek  \
# 0  Played  4406278        38
# 1  Played  4406278        38
# 2  Played  4406278        38
# 3  Played  4406278        38
# 4  Played  4406278        38
#
#                                            teamsData  seasonId  \
# 0  {'3162': {'scoreET': 0, 'coachId': 251025, 'si...    181248
# 1  {'3158': {'scoreET': 0, 'coachId': 210119, 'si...    181248
# 2  {'3173': {'scoreET': 0, 'coachId': 251044, 'si...    181248
# 3  {'3165': {'scoreET': 0, 'coachId': 272970, 'si...    181248
# 4  {'3166': {'scoreET': 0, 'coachId': 20481, 'sid...    181248
#
#                dateutc  winner                                venue     wyId  \
# 0  2018-05-20 18:45:00    3161                                       2576335
# 1  2018-05-20 18:45:00    3158  MAPEI Stadium - Città del Tricolore  2576336
# 2  2018-05-20 16:00:00    3173                                       2576329
# 3  2018-05-20 16:00:00    3165                                       2576330
# 4  2018-05-20 16:00:00    3163                                       2576331
#
#                            label                              date  \
# 0  Lazio - Internazionale, 2 - 3  May 20, 2018 at 8:45:00 PM GMT+2
# 1         Sassuolo - Roma, 0 - 1  May 20, 2018 at 8:45:00 PM GMT+2
# 2     Cagliari - Atalanta, 1 - 0  May 20, 2018 at 6:00:00 PM GMT+2
# 3      Chievo - Benevento, 1 - 0  May 20, 2018 at 6:00:00 PM GMT+2
# 4       Udinese - Bologna, 1 - 0  May 20, 2018 at 6:00:00 PM GMT+2
#
#                                             referees duration  competitionId
# 0  [{'refereeId': 377206, 'role': 'referee'}, {'r...  Regular            524
# 1  [{'refereeId': 377255, 'role': 'referee'}, {'r...  Regular            524
# 2  [{'refereeId': 377247, 'role': 'referee'}, {'r...  Regular            524
# 3  [{'refereeId': 377246, 'role': 'referee'}, {'r...  Regular            524
# 4  [{'refereeId': 377254, 'role': 'referee'}, {'r...  Regular            524

# %%
#The Juve - Napoli game has ID 2576295

# %%
# Let's import our Serie A data

df_events_SerieA =  pd.read_json('events_Italy.json',encoding='utf-8')
df_events_SerieA.head()
# Out:
#    eventId           subEventName                                      tags  \
# 0        8            Simple pass                            [{'id': 1801}]
# 1        8            Simple pass                            [{'id': 1801}]
# 2        7                  Touch                                        []
# 3        1  Ground attacking duel  [{'id': 504}, {'id': 703}, {'id': 1801}]
# 4        1  Ground attacking duel  [{'id': 503}, {'id': 703}, {'id': 1801}]
#
#    playerId                                 positions  matchId  \
# 0      8327  [{'y': 52, 'x': 49}, {'y': 44, 'x': 43}]  2575959
# 1     20438  [{'y': 44, 'x': 43}, {'y': 17, 'x': 36}]  2575959
# 2      8306  [{'y': 17, 'x': 36}, {'y': 56, 'x': 78}]  2575959
# 3      8306  [{'y': 56, 'x': 78}, {'y': 15, 'x': 64}]  2575959
# 4      8306  [{'y': 15, 'x': 64}, {'y': 15, 'x': 72}]  2575959
#
#             eventName  teamId matchPeriod  eventSec subEventId         id
# 0                Pass    3158          1H  2.530536         85  180423957
# 1                Pass    3158          1H  3.768418         85  180423958
# 2  Others on the ball    3158          1H  4.868265         72  180423959
# 3                Duel    3158          1H  8.114676         11  180423960
# 4                Duel    3158          1H  8.647892         11  180423961

# %%
# we only keep events from the Juve - Napoli game we are interested in

df_events_juve_napoli = df_events_SerieA[df_events_SerieA['matchId'] == 2576295]
df_events_juve_napoli.head()
# Out:
#         eventId           subEventName            tags  playerId  \
# 573095        8            Simple pass  [{'id': 1801}]     21385
# 573096        8            Simple pass  [{'id': 1801}]      3300
# 573097        8              High pass  [{'id': 1802}]     25726
# 573098        5  Ball out of the field              []         0
# 573099        3               Throw in  [{'id': 1801}]     20588
#
#                                           positions  matchId     eventName  \
# 573095     [{'y': 50, 'x': 50}, {'y': 53, 'x': 38}]  2576295          Pass
# 573096     [{'y': 53, 'x': 38}, {'y': 52, 'x': 38}]  2576295          Pass
# 573097    [{'y': 52, 'x': 38}, {'y': 100, 'x': 82}]  2576295          Pass
# 573098  [{'y': 100, 'x': 82}, {'y': 100, 'x': 100}]  2576295  Interruption
# 573099       [{'y': 0, 'x': 17}, {'y': 35, 'x': 3}]  2576295     Free Kick
#
#         teamId matchPeriod   eventSec subEventId         id
# 573095    3187          1H   1.265726         85  245487374
# 573096    3187          1H   2.087491         85  245487375
# 573097    3187          1H   3.184110         83  245487376
# 573098    3187          1H   7.898538         50  245487378
# 573099    3159          1H  11.326685         36  245487369

# %%
# we find Pjanic id

pjanic = df_players[df_players['shortName'] == 'M. Pjanić']
pjanic
# Out:
#                                            passportArea  weight firstName  \
# 1482  {'name': 'Luxembourg', 'id': '442', 'alpha3cod...      74   Miralem
#
#      middleName lastName currentTeamId   birthDate  height  \
# 1482              Pjanić          3159  1990-04-02     180
#
#                                                    role  \
# 1482  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
#
#                                               birthArea   wyId   foot  \
# 1482  {'name': 'Bosnia-Herzegovina', 'id': '70', 'al...  20443  right
#
#       shortName currentNationalTeamId
# 1482  M. Pjanić                  null

# %%
# we find Jorginho id

jorginho = df_players[df_players['shortName'] == 'Jorginho']
jorginho
# Out:
#                                            passportArea  weight   firstName  \
# 1658  {'name': 'Italy', 'id': '380', 'alpha3code': '...      65  Jorge Luiz
#
#      middleName      lastName currentTeamId   birthDate  height  \
# 1658             Frello Filho          3187  1991-12-20     180
#
#                                                    role  \
# 1658  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
#
#                                               birthArea   wyId   foot  \
# 1658  {'name': 'Brazil', 'id': '76', 'alpha3code': '...  21315  right
#
#      shortName currentNationalTeamId
# 1658  Jorginho                  3757

# %%
# we store events for both players

df_events_pjanic = df_events_juve_napoli[df_events_juve_napoli['playerId'] == 20443]
df_events_jorginho = df_events_juve_napoli[df_events_juve_napoli['playerId'] == 21315]

# %%
# we only keep relevant events for both players, with a distinction between passes and other relevant events
relevant_events = ['Duel', 'Pass', 'Shot', 'Free Kick']

df_events_pjanic = df_events_pjanic[df_events_pjanic['eventName'].isin(relevant_events)]
df_events_jorginho = df_events_jorginho[df_events_jorginho['eventName'].isin(relevant_events)]
df_passes_pjanic = df_events_pjanic[df_events_pjanic['eventId'] == 8]
df_passes_jorginho = df_events_jorginho[df_events_jorginho['eventId'] == 8]

# %%
df_passes_pjanic.head()
# Out:
#         eventId subEventName                                        tags  \
# 573105        8  Simple pass                              [{'id': 1801}]
# 573107        8    High pass                              [{'id': 1801}]
# 573126        8  Simple pass                [{'id': 1401}, {'id': 1801}]
# 573220        8  Simple pass  [{'id': 1401}, {'id': 1001}, {'id': 1802}]
# 573225        8  Simple pass                              [{'id': 1801}]
#
#         playerId                                 positions  matchId eventName  \
# 573105     20443   [{'y': 55, 'x': 28}, {'y': 2, 'x': 39}]  2576295      Pass
# 573107     20443  [{'y': 30, 'x': 31}, {'y': 84, 'x': 31}]  2576295      Pass
# 573126     20443  [{'y': 62, 'x': 63}, {'y': 47, 'x': 63}]  2576295      Pass
# 573220     20443   [{'y': 26, 'x': 25}, {'y': 0, 'x': 31}]  2576295      Pass
# 573225     20443  [{'y': 51, 'x': 26}, {'y': 76, 'x': 13}]  2576295      Pass
#
#         teamId matchPeriod    eventSec subEventId         id
# 573105    3159          1H   26.160914         85  245487395
# 573107    3159          1H   33.120179         83  245487399
# 573126    3159          1H  120.169376         85  245487410
# 573220    3159          1H  352.941005         85  245487509
# 573225    3159          1H  432.992312         85  245487518

# %%
# we check if Pjanic passes were successful or failed

pass_state = []

for index,row in df_passes_pjanic.iterrows():
    for value in row['tags'][-1].values():
        if value == 1801:
            pass_state.append('successful')
        elif value == 1802:
            pass_state.append('failed')

# %%
df_passes_pjanic['pass_status'] = pass_state
# Out:
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# we check if Jorginho passes were successful or failed

pass_state = []

for index,row in df_passes_jorginho.iterrows():
    for value in row['tags'][-1].values():
        if value == 1801:
            pass_state.append('successful')
        elif value == 1802:
            pass_state.append('failed')

# %%
df_passes_jorginho['pass_status'] = pass_state
# Out:
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# we get starting and ending positions for all Pjanic passes using the powerful re library

y_start = []
x_start = []
y_end = []
x_end = []

for index,row in df_passes_pjanic.iterrows():
    int_list = [int(s) for s in re.findall(r'\b\d+\b', str(row['positions']))]
    y_start.append(0.8*int_list[0])
    x_start.append(1.2*int_list[1])
    y_end.append(0.8*int_list[2])
    x_end.append(1.2*int_list[3])
    
df_passes_pjanic['y_start'] = y_start
df_passes_pjanic['x_start'] = x_start
df_passes_pjanic['y_end'] = y_end
df_passes_pjanic['x_end'] = x_end
# Out:
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# we get starting and ending positions for all Pjanic events using the powerful re library

y_start = []
x_start = []
y_end = []
x_end = []

for index,row in df_events_pjanic.iterrows():
    int_list = [int(s) for s in re.findall(r'\b\d+\b', str(row['positions']))]
    y_start.append(0.8*int_list[0])
    x_start.append(1.2*int_list[1])
    y_end.append(0.8*int_list[2])
    x_end.append(1.2*int_list[3])
    
df_events_pjanic['y_start'] = y_start
df_events_pjanic['x_start'] = x_start
df_events_pjanic['y_end'] = y_end
df_events_pjanic['x_end'] = x_end

# %%
# we create 2 dataframes: one with successful passes and the other with failed ones

df_successful_passes_pjanic = df_passes_pjanic[df_passes_pjanic['pass_status'] == 'successful']
df_failed_passes_pjanic = df_passes_pjanic[df_passes_pjanic['pass_status'] == 'failed']

# %%
#Pjanic heatmap

fig, ax = plt.subplots()
fig.set_size_inches(7, 5)
#ax=fig.add_subplot(1,1,1)
draw_pitch(ax) #overlay our different objects on the pitch
plt.title("Pjanic Heatmap")
plt.ylim(-2, 82)
plt.xlim(-2, 122)
plt.axis('on')

for i in range(len(df_successful_passes_pjanic)):
    # annotate draw an arrow from a current position to pass_end_location
    ax.annotate("", xy = (df_successful_passes_pjanic.iloc[i]['x_end'], df_successful_passes_pjanic.iloc[i]['y_end']), xycoords = 'data',
               xytext = (df_successful_passes_pjanic.iloc[i]['x_start'], df_successful_passes_pjanic.iloc[i]['y_start']), textcoords = 'data',
               arrowprops=dict(arrowstyle="->",connectionstyle="arc3", color = "blue"),)
    
for i in range(len(df_failed_passes_pjanic)):
    # annotate draw an arrow from a current position to pass_end_location
    ax.annotate("", xy = (df_failed_passes_pjanic.iloc[i]['x_end'], df_failed_passes_pjanic.iloc[i]['y_end']), xycoords = 'data',
               xytext = (df_failed_passes_pjanic.iloc[i]['x_start'], df_failed_passes_pjanic.iloc[i]['y_start']), textcoords = 'data',
               arrowprops=dict(arrowstyle="->",connectionstyle="arc3", color = "red"),)

x_coord = df_events_pjanic['x_start'].tolist()
y_coord = df_events_pjanic['y_start'].tolist()

#shades: give us the heat map we desire
# n_levels: draw more lines, the larger n, the more blurry it looks
sns.kdeplot(x_coord, y_coord, shade = "True", color = "green", n_levels = 15)
plt.show()

print("Sucessful pases are in blue and failed ones in red")
# Out:
# Sucessful pases are in blue and failed ones in red

# %% [raw]
# We notice a very strong presence in the center of the pitch, with was predictible as Pjanic is a central Midfielder (at ease with both 6 and 8 positions). We also notice that Pjanic has only missed 1 (!) pass on the 44 he attempted. This is an excellent performance, even for such a pass master (Pjanic is famous for his passing and free-kick kills)

# %%
#Let's do the same thing for Jorginho

# %%
# we get starting and ending positions for all Jorginho passes using the powerful re library

y_start = []
x_start = []
y_end = []
x_end = []

for index,row in df_passes_jorginho.iterrows():
    int_list = [int(s) for s in re.findall(r'\b\d+\b', str(row['positions']))]
    y_start.append(0.8*int_list[0])
    x_start.append(1.2*int_list[1])
    y_end.append(0.8*int_list[2])
    x_end.append(1.2*int_list[3])
    
df_passes_jorginho['y_start'] = y_start
df_passes_jorginho['x_start'] = x_start
df_passes_jorginho['y_end'] = y_end
df_passes_jorginho['x_end'] = x_end
# Out:
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Nathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# we get starting and ending positions for all Jorginho events using the powerful re library

y_start = []
x_start = []
y_end = []
x_end = []

for index,row in df_events_jorginho.iterrows():
    int_list = [int(s) for s in re.findall(r'\b\d+\b', str(row['positions']))]
    y_start.append(0.8*int_list[0])
    x_start.append(1.2*int_list[1])
    y_end.append(0.8*int_list[2])
    x_end.append(1.2*int_list[3])
    
df_events_jorginho['y_start'] = y_start
df_events_jorginho['x_start'] = x_start
df_events_jorginho['y_end'] = y_end
df_events_jorginho['x_end'] = x_end

# %%
df_successful_passes_jorginho = df_passes_jorginho[df_passes_jorginho['pass_status'] == 'successful']
df_failed_passes_jorginho = df_passes_jorginho[df_passes_jorginho['pass_status'] == 'failed']

# %%
#Jorginho heatmap

fig, ax = plt.subplots()
fig.set_size_inches(7, 5)
#ax=fig.add_subplot(1,1,1)
draw_pitch(ax) #overlay our different objects on the pitch
plt.title("Jorginho's Heatmap")
plt.ylim(-2, 82)
plt.xlim(-2, 122)
plt.axis('on')

for i in range(len(df_successful_passes_jorginho)):
    # annotate draw an arrow from a current position to pass_end_location
    ax.annotate("", xy = (df_successful_passes_jorginho.iloc[i]['x_end'], df_successful_passes_jorginho.iloc[i]['y_end']), xycoords = 'data',
               xytext = (df_successful_passes_jorginho.iloc[i]['x_start'], df_successful_passes_jorginho.iloc[i]['y_start']), textcoords = 'data',
               arrowprops=dict(arrowstyle="->",connectionstyle="arc3", color = "blue"),)
    
for i in range(len(df_failed_passes_jorginho)):
    # annotate draw an arrow from a current position to pass_end_location
    ax.annotate("", xy = (df_failed_passes_jorginho.iloc[i]['x_end'], df_failed_passes_jorginho.iloc[i]['y_end']), xycoords = 'data',
               xytext = (df_failed_passes_jorginho.iloc[i]['x_start'], df_failed_passes_jorginho.iloc[i]['y_start']), textcoords = 'data',
               arrowprops=dict(arrowstyle="->",connectionstyle="arc3", color = "red"),)

x_coord = df_events_jorginho['x_start'].tolist()
y_coord = df_events_jorginho['y_start'].tolist()

#shades: give us the heat map we desire
# n_levels: draw more lines, the larger n, the more blurry it looks
sns.kdeplot(x_coord, y_coord, shade = "True", color = "green", n_levels = 15)
plt.show()

print("Sucessful passes are in blue and failed ones in red")
# Out:
# Sucessful passes are in blue and failed ones in red

# %% [raw]
# Jorginho's heatmap hows us that he played at a overall more advanced position than Pjanic, still in midfield but more as a number 8, with a strong preference for the right side of the pitch.
# We notice a hugh number of passes, with 16 faied passes out of 114. This still gives us a very good ratio, but maybe a little lower than what we are used to with Jorginho (who is known for being one of the most accurate passers in football world).
#
# In my opinion this unual high number of failed passes can be explained by Jorginho's high position on the pitch (as a number 8), whereas his favourite position is as a number 6 (a bit lower on the pitch). A higher position means being closer to opponent's goals and having to take more risks when attempting passes to reach your team's forwards.

# %% [raw]
# Overall, Pjanic's better pass accuracy ratio can mainly be explained by:
# - a smaller number of passes (44 versus 114). Naturally, the more you pass the more you can fail
# - a lower positon on the pitch and as a result less risky passes (we see on Pjanic's heatmap that contrary to Jorginho, he didn't even try to reach a teammate in the opponent's penalty area)
# - maybe an unusually high position for Jorginho, who is used to play as a number 6 lower on the pitch
